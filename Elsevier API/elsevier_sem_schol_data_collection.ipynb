# %%
import elsapy
from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
import json
import urllib

import httpx
import time
import requests
import textwrap

import pandas as pd
import numpy as np
import sys

import config

# %%
sys.path.append('C:/Users/ad882/OneDrive - University of Exeter\Miscellaneous/Research-Paper-Explorer')

# %%
# Specify the keys and tokens

api_key = config.elsevier_api_key
inst_token = config.elsevier_inst_token


headers = {
        'Accept': 'application/json',
        'X-ELS-APIKey': api_key,
        'X-ELS-Insttoken': inst_token
    }

# %%
json_data = []

query = 'sexism%20OR%20misogy'
fields = 'dc:title' # Just focus on titles
year = 2013

scopus_search_url = 'https://api.elsevier.com/content/search/scopus?'
offset = 0

print(f'Starting {year} now')

while True: # As long as the url exists
    # print('Requesting', url)
    # print('Offset', offset)
    # Make the request
    responses = requests.get(f'{scopus_search_url}query={query}&field={fields}&date={year}&start={offset}&view=STANDARD', headers=headers, stream = True)
    json = responses.json()
    if 'search-results' in json:
        json = json['search-results']
        # Check if any values are left
        if 'entry' in json : # The 'entry' key only exists if the request was successful, meaning values are left
            offset = offset + 25
            # If data found, add them to the variable, 
            # add them to the list and move to the next offset
            json_data.extend(json['entry'])
            time.sleep(3)
        else:
            year += 1
            if year > 2022:
                print(f'Reached {year}, so ending search now')
                break
            else: 
                offset = 0
                responses = requests.get(f'{scopus_search_url}query={query}&field={fields}&date={year}&start={offset}&view=STANDARD', headers=headers, stream = True)
                json = responses.json()
                if 'search-results' in json:
                    json = json['search-results']
                    if 'entry' in json : # The 'entry' key only exists if the request was successful, meaning values are left
                        offset = offset + 25
                        json_data.extend(json['entry'])
                        time.sleep(3)
                        print(f'Starting {year} now')
                    else:
                        print(f'Reached here')
                        continue
                else:
                    print(f'Reached the year {year}, but no search results')
                    continue
    else:
        print(f'Response 400 Bad request') # check the query for the request then
        break
# Out:
# Starting 2013 now
# Starting 2014 now
# Starting 2015 now
# Starting 2016 now
# Starting 2017 now
# Starting 2018 now
# Starting 2019 now
# Starting 2020 now
# Starting 2021 now
# Starting 2022 now
# Response 400 Bad request

# %%
titles = pd.DataFrame(json_data)
titles = titles.drop_duplicates(subset='dc:title')
len(titles)
# Out:
# 32009

# %%
titles
# Out:
#        @_fa                                          prism:url  \
# 0      true  https://api.elsevier.com/content/abstract/scop...
# 1      true  https://api.elsevier.com/content/abstract/scop...
# 2      true  https://api.elsevier.com/content/abstract/scop...
# 3      true  https://api.elsevier.com/content/abstract/scop...
# 4      true  https://api.elsevier.com/content/abstract/scop...
# ...     ...                                                ...
# 32204  true  https://api.elsevier.com/content/abstract/scop...
# 32205  true  https://api.elsevier.com/content/abstract/scop...
# 32206  true  https://api.elsevier.com/content/abstract/scop...
# 32207  true  https://api.elsevier.com/content/abstract/scop...
# 32208  true  https://api.elsevier.com/content/abstract/scop...
#
#                                                 dc:title
# 0      The scale of ethical attitude toward ethnic hu...
# 1      Womanist ways and pentecostalism: The work of ...
# 2      A feminist pentecostal theological anthropolog...
# 3      Dying to get out of the asylum: Mortality and ...
# 4      Citizenship without representation? Blackface,...
# ...                                                  ...
# 32204  Gender disparities among leadership in academi...
# 32205  Towards a digital football studies: current tr...
# 32206  Gender and potential impacts on decision-makin...
# 32207  Women representation in academic and leadershi...
# 32208  Parenting styles and its relations with person...
#
# [32009 rows x 3 columns]

# %% [markdown]
# ## Using the Semantic Scholar API now

# %%
def url_encode(text):
    text = urllib.parse.quote(str(text))
    return text

# %%
list_titles = titles['dc:title'].apply(url_encode)
# Store it as a list
list_titles = list_titles.to_list()

# %%
api_key = config.semantic_api_key

headers = {
        'Content-type': 'application/json',
        'x-api-key': api_key,
        'Connection': 'close'
    }

# %%
# Automated, but without the API credentials
limit= 1 # Because we only want exact match
json_data = []
print('Starting to collect results')

for title in list_titles:
    # Make the request
    #print(f'{title}')
    session = requests.Session()
    # What the TimeoutHTTPAdapter class actually does is it overrides any call-specific timeout arguments 
    # with the instance-defined timeout attribute when sending requests.
    # So only using the max retries argument here and calling the timeout in the calls itself
    adapter = requests.adapters.HTTPAdapter(max_retries=20) # Mounts a custom adapter to a given schema. Here just increases the number of allowed retries.
    # Now let's mount the instance of the custom TimeoutHTTPAdapter class with the session object, and then the GET request was specifically executed via the 
    # session object (session.get()), not via the requests.get() global function.       
    session.mount("https://", adapter)
    # Actually the timeout argument is a bit more complex: you can specify a tuple of two values. 
    # The first value is the connect timeout and the second is the read timeout.
    # e.g., timeout=Timeout(connect=2, read=60)
    responses = session.get(f'https://api.semanticscholar.org/graph/v1/paper/search?query=title:({title})&limit={limit}', headers=headers, stream = True, timeout= (50, 120))
    json = responses.json()
    responses.close()
    # Check if the sum of offset and limit exceeds 10000 or if any values are left
    # To avoid {'error': 'offset + limit must be < 10000'} Why? Check the About.md for answers
    #if 'data' in json: 
    if ('data' not in json) or (not json['data']):
        #print('Going to the next title')
        continue
    else:
        try:
            paper_id = json['data'][0]['paperId']
            responses = session.get(f'https://api.semanticscholar.org/graph/v1/paper/{paper_id}?fields=url,abstract,authors,title,venue,year,publicationTypes,referenceCount,citationCount,influentialCitationCount,isOpenAccess,fieldsOfStudy,tldr', headers=headers, stream = True, timeout= (50, 120))
            json = responses.json()
            responses.close()
            if 'title' in json: 
                try:
                    # The next step is needed. Otherwise will give unhashable dict error
                    json_extension = {}
                    # Add all the different kinds of objects which are of interest
                    json_extension['Title'] = json['title']
                    json_extension['Authors'] = json['authors']
                    json_extension['Abstract'] = json['abstract']
                    json_extension['Venue'] = json['venue']
                    json_extension['Year'] = json['year']
                    json_extension['Publication_Type'] = json['publicationTypes']
                    json_extension['Reference_Count'] = json['referenceCount']
                    json_extension['Citation_Count'] = json['citationCount']
                    json_extension['Influential_Citation_Count'] = json['influentialCitationCount']
                    json_extension['Open_Access'] = json['isOpenAccess']
                    json_extension['fieldsOfStudy'] = json['fieldsOfStudy']
                    json_extension['TLDR'] = json['tldr']
                    json_data.append(json_extension)
                    time.sleep(5)
                    print(f'Results of {paper_id} started')
                except requests.exceptions.Timeout:
                    print("Paper information timeout occurred")
                    continue
            else:
                print(f'No data could be retrieved')
                continue
        except requests.exceptions.Timeout:
            print("Search paper timeout occurred")
            continue
# Out:
# Starting to collect results
# Results of 13a5af8e07a219eb0e44ca628f5e5afc1d580f75 started
# Results of 3f08db4b3f1b4ae0724e17a9cda4e5b6c05c36ad started
# Results of b0fb71ea3120011b0a11e51158ade0bdfd50cc3a started
# Results of 16e2e7522907c43202fbfd1236e892e085345da5 started
# Results of 2f872da85c2e1dfed1bfcda2921107ac27d5bf54 started
# Results of dd129191b001189a673649712626d05b6f51fb48 started
# Results of 0b496d7bd574eb6a1711004efa4e424e2a5aa7c0 started
# Results of 8c72da105fdc10ad918eb3732fd1d491be1803d1 started
# Results of 9a948d0ae399d4f1f012bfb4f2a3774a1644b14f started
# Results of 96f983b1c853b15d6d4fb2dfbb27d3b13417b416 started
# Results of a0d1ddea097b95f9460e9b0e4a3aabedeb7710b1 started
# Results of 3faba61266dc7ca97398d75f8ee26ef1e666aea9 started
# Results of 6e95bfb6ee64b9423848fecd665a43c11fcbae6d started
# Results of e770cc9e56c700ee6edc488a6ad2a8ce0609b33f started
# Results of 31591aa605e4c482a22a1e09760ebfaf95368ee9 started
# Results of ad6a4d6fcaec301f08443ef1095a0268077007da started
# Results of f536a05976ef7a6b454df9fc12cb0a6bfc0ce27c started
# Results of 18c3deab9ddd33e02ffd5d9874e52b9159f372e2 started
# Results of 25a73efc58b5d777eed94da3fc2b46da310fb01e started
# Results of 254396b2c706d9847f427bf4304abcd84c197947 started
# Results of 170cbdf4eead7a119c78b6ff50e93e288c5be6e3 started
# Results of cbcb5e869647c6eb31126a8603e9b46c3b604730 started
# Results of 665b47aac6f3e64e69034231516c6c69ff64ffbd started
# Results of 5c5d47209fddb3ee478352e332bf8751423990b1 started
# Results of f8ab3783fb7adddfc01018a6210fd5bc2e6957e3 started
# Results of 59f4bb13dfff1b7ce70b27b45da3b1421f594547 started
# Results of 6133fd6da57b7e8f110afb2887f3cbf1258b1fb1 started
# Results of 93ccce36b007cc96a8142d9a1b15b3d3ef5336a4 started
# Results of 35eaa889218ea32b8518673774400bf6fb848ef3 started
# Results of 355adb9a4c1a8043abb10ba0c212ad714c9503eb started
# Results of c710b126fccff0578bd4e3718851cdd420cbb402 started
# Results of 7c8b3bee56861932d94c7a68df570d93f9444ea0 started
# Results of 40ebc5402045ae9730073f58bed70c45f19ea04d started
# Results of 70c7dc5839002f391824ea26b329b8e66c7c9723 started
# Results of 6ba67071f02baf1b5e27439fa79d08474ec1a72f started
# Results of a8ac87e952c007382b00e6c40c390e15b15d3128 started
# Results of 18f240b14dc0597c851ab7854c9b600540be25de started
# Results of 5f02f7064141ad11f5fbd394d6fa0d1d00e00682 started
# Results of 8cecc0fdb3a867aa133255199c4eda2aa3c05c96 started
# Results of 67cc6cc719d803808c4a4a6c94ccf7be9b613fd5 started
# Results of 0491d07a5f36b74fafa4dffd3cc4948d726e5ada started
# Results of 5cdf63cf1e2ee940388f98a0c6cfd7c525cb8301 started
# Results of bd755e120fb710e087b20abcd6657ca0a2c90335 started
# Results of f041b03f76bd004d9d0aef099369da511a36b47f started
# No data could be retrieved
# Results of c62818b3841de087ea2612f036efef235c6569bc started
# Results of a5275f96923f67a1fe7485946df265daa6d84ba3 started
# Results of 87e5d2b34f7d71cd53f81d1c66a2ae5fe80177a1 started
# Results of 3d7a5cc926982920fc606c0dd7f693705d2cdbf3 started
# Results of f59d119842c6c88a39d66ce2b1ad6b2223acaad5 started
# Results of 68cf82969a8ede929d7d5d328a007a7966e8202b started
# Results of cc448112dbbf5ea11ffc9f2e960a3fde7469c626 started
# Results of 821124befd2318e13bb7927635c5c9d46172fd3b started
# Results of 833a1513b6693ec076588fcc2d665700f008b041 started
# Results of c98d61517ad29a1a8365e442c996231b6d895241 started
# Results of cc277fa06bee40ae89570a956383fd9647bf3245 started
# Results of 471f8219279b1b65111d969eba1b9b0a124d3d57 started
# Results of 8725c6aeaeb0aaa70e5c1a87031eb526befc2479 started
# Results of 3b9ce488c72a99b2f23be44f0a4859bd8a9b846f started
# Results of 07b0c7e7c1997ca32139a1b1b23e022918570a79 started
# Results of bad1e46c656fb13b3eed6b29b779e3ef3ee6dc99 started
# Results of 7f2b351fe1093050f5fcebaeb98190f5f733bde2 started
# Results of 1a5f671eb202df1add93237c06f948073133f41a started
# Results of 08e78b20f7c96947898c77fbf7d63f502086639f started
# Results of 34536d7a6d7b61198a8b0e4dc187e7b9ff8e4648 started
# Results of 09f97901219f597666750f0ba0d0dcc17551eeab started
# Results of 1538fef62d8be04663657b34b8b473acc2e7fc20 started
# Results of ca84e50850cc5a1ecd470c40fe2438570c5d3a88 started
# Results of 705dd119ae245fe743159399a05f83ef5d430310 started
# Results of b27391eef308f63029272ca223c97119d760ba81 started
# Results of 338f180d61b14b68e8b6b4132489741b40b0c7ba started
# Results of b5e62fbf1c1efba4ff9d06dc6d3ccc10cd97e1a9 started
# Results of 60cedbf8153a3db78ab61fb4f5fd6ce2c133b8d7 started
# Results of 4f7afa31f40ffaebe5948069afbd4ca76cc5761b started
# Results of 6b1f2de86fd4893f7ddaae453b79b30b4d18b7e9 started
# Results of cc853dd071021ecff010c34fe5a0bd991ca89bcd started
# Results of f54974da5a2264837621418d2308b9ad01d930e0 started
# Results of 1c0f134d24e992a2521e8d2401965b0648b2aabf started
# Results of 6d50fab57cc78d575b66a004b576bcc8dea03115 started
# Results of e53daa45966524356245ba8124509da3303301ad started
# Results of f943a7737cdf432f67561ebe08f2f5eb041f9cfa started
# Results of 83ea0cbd2b1bdc8c19332d9e1d5bfbcf8a27f4f1 started
# Results of d4ddceca601ffae3fb1aec81cccf450cfaac1e5a started
# Results of c9a23bbf1565ad0d9d05aab8554b2593d0c943de started
# Results of e38e86a107422164376de90e47ed6981a045c4cd started
# Results of d08dc11677351360c76982eb0d56a5b57c6f4fd0 started
# Results of 58a86789a21fce2b4032b86f088a2479f7bd2760 started
# Results of bcc5a3eca81ce05724bb5cf9d80b73956708542a started
# Results of b11c96fb228173a166d251f2934e70b1c02ddf8c started
# Results of 88f1c818e79011a0da2bb9b6de8d6057942e4fcc started
# Results of 85bf5cfbd934c97b2bf1453f99ecaf40055a50d6 started
# Results of f405eb2b61dbcec8f32e2ee11931bf9d0b0a0355 started
# Results of c0edd0e3d840fa2bdfcbe3f2e2b418f9010c6261 started
# Results of 171fb57b6740ce74728b11734bbd31a463bc7e5f started
# Results of 812b4d56b194e6499a3a0f51d6eb3610856cd6d6 started
# Results of a0afbf7642ac42ad0fc65f38357fbd1007915133 started
# Results of 58ad9ede97a6f4c9789293ecffaf4cd5c3c91044 started
# Results of 4c62734bd959b4af4ead2005fa3a462c0722686b started
# Results of afae8d44c17a4c389a80df9a30df6c795c10b1f7 started
# Results of c8f814c43dd98022d0a2e84f36ac7e53212c8361 started
# Results of a12d1b17379d494f592b71bca581aacb5bda6fa1 started
# Results of 001d413072cb26f5bff858429b992b8893864e1f started
# Results of e0b7d541a7cb8254982469498fab9ef2d14eae88 started
# Results of 64721c9c25521a06a5affab15a4a394487059d48 started
# Results of b75dcae99a4bd454ed106bdcb5ca37a0dd7d3091 started
# Results of 0e7d89776bf3b788bdd4235193ffea1450e9f589 started
# Results of e11a25962cb9d0262da1013c0e1852b74d6d9f52 started
# Results of 9df00b286f7cac88abd44ccd346b63d0ca4cec87 started
# Results of fd09d26002004bcdc543cbbb18cd549eaf23866e started
# Results of 2fa12792fb5a4dc21d2f147907c3f97e5f0b44d9 started
# Results of 1c34468fd3161b2f7e18265c48df9754be0cbe05 started
# Results of 7e918bc5b9958d8b545ce10cc4a615d20b24f363 started
# Results of 4f898ff5172ab40cbb73978dd2cb1d733b6953b4 started
# Results of e247d769f1118765815c17a9ad9db9a6e923ea25 started
# Results of 3ee6238c013201707a7c062f860a345c8d12196b started
# Results of 7fdfb8df33ed96b33d92e99c3be0e86b15a7f5e3 started
# Results of 44045539ed87ed71328c61e0fd6b01314179d303 started
# Results of a3ab5a78324812b152edd5a153740e9a03afac05 started
# Results of 42090735587a9377907c4edd7464e794456e8823 started
# Results of f5733fba394955b3dc53b72ad441623e6c84a004 started
# Results of d9392d7f37bd461b001fb3cbb46b247bccd67f4d started
# Results of 5c24559905bcf7d9bd5398a01af49f531c8a5bd2 started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 20
#      16 session.mount("https://", adapter)
#      17 # Actually the timeout argument is a bit more complex: you can specify a tuple of two values.
#      18 # The first value is the connect timeout and the second is the read timeout.
#      19 # e.g., timeout=Timeout(connect=2, read=60)
# ---> 20 responses = session.get(f'https://api.semanticscholar.org/graph/v1/paper/search?query=title:({title})&limit={limit}', headers=headers, stream = True, timeout= (50, 120))
#      21 json = responses.json()
#      22 responses.close()
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\urllib3\connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File c:\Users\ad882\OneDrive - University of Exeter\Miscellaneous\Research-Paper-Explorer\venv\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(json_data)
df = df.drop_duplicates(subset=['Title', 'Abstract'])
df['index'] = df.index
df
# Out:
#                                                  Title  \
# 0    The Scale of Ethical Attitude toward Ethnic Hu...
# 1    A Feminist Pentecostal Theological Anthropolog...
# 2    Dying to Get Out of the Asylum: Mortality and ...
# 3    Citizenship without representation? Blackface,...
# 4    Schools, Sex Education, and Support for Sexual...
# ..                                                 ...
# 446  Racial Diversity, Religion, and Morality: Exam...
# 447  Penalizing Men Who Request a Family Leave: Is ...
# 448  Comparative study of the quality of life assoc...
# 449  Rethinking racial formation theory: a systemic...
# 450  Stigmatization of individuals with sexually tr...
#
#                                                Authors  \
# 0    [{'authorId': '1391152009', 'name': 'E. F. Hag...
# 1    [{'authorId': '40164727', 'name': 'Lisa P. Ste...
# 2    [{'authorId': '2144036837', 'name': 'D. Wright...
# 3     [{'authorId': '73721487', 'name': 'Adam Haupt'}]
# 4    [{'authorId': '1401799456', 'name': 'David McC...
# ..                                                 ...
# 446  [{'authorId': '6004434', 'name': 'Samuel L. Pe...
# 447  [{'authorId': '3156773', 'name': 'L. Rudman'},...
# 448  [{'authorId': '145894542', 'name': 'F. Ferrand...
# 449  [{'authorId': '93292986', 'name': 'J. Feagin'}...
# 450  [{'authorId': '32189050', 'name': 'Lyndsay R. ...
#
#                                               Abstract  \
# 0    Research on ethnic humor has been centered on ...
# 1    Abstract In this article I focus on developing...
# 2    This article examines the status of lunatic ca...
# 3    Abstract This article explores Die Antwoord's ...
# 4    School-based adolescent sexual health educatio...
# ..                                                 ...
# 446                                               None
# 447  Men who request a family leave are viewed as p...
# 448  ObjectiveBecause the experience of menopause v...
# 449  Abstract In this theoretical analysis of US ra...
# 450  There has been little experimental research ex...
#
#                                    Venue  Year  \
# 0                                         2013
# 1                                         2013
# 2    Bulletin of The History of Medicine  2013
# 3                                         2013
# 4                                         2013
# ..                                   ...   ...
# 446                                       2013
# 447                                       2013
# 448                            Menopause  2013
# 449                                       2013
# 450                                       2013
#
#                     Publication_Type  Reference_Count  Citation_Count  \
# 0                               None               77               5
# 1                               None                1               1
# 2                   [JournalArticle]               74               4
# 3                               None               41               2
# 4                           [Review]               84              40
# ..                               ...              ...             ...
# 446                         [Review]               41              10
# 447                             None               45             391
# 448  [JournalArticle, Study, Review]               59              46
# 449                             None               97             162
# 450                             None               44              12
#
#      Influential_Citation_Count  Open_Access fieldsOfStudy  \
# 0                             0         True  [Psychology]
# 1                             0        False   [Sociology]
# 2                             1        False    [Medicine]
# 3                             0        False   [Sociology]
# 4                             6        False  [Psychology]
# ..                          ...          ...           ...
# 446                           0        False   [Sociology]
# 447                          21        False  [Psychology]
# 448                           0        False    [Medicine]
# 449                           4        False   [Sociology]
# 450                           0        False  [Psychology]
#
#                                                   TLDR  index
# 0                                                 None      0
# 1                                                 None      1
# 2    {'model': 'tldr@v2.0.0', 'text': 'Cause of dea...      2
# 3                                                 None      3
# 4                                                 None      4
# ..                                                 ...    ...
# 446                                               None    446
# 447                                               None    447
# 448  {'model': 'tldr@v2.0.0', 'text': 'This epidemi...    448
# 449                                               None    449
# 450                                               None    450
#
# [450 rows x 13 columns]

# %%
df.Year.unique()
# Out:
# array([2013, 1999, 1988, 2022, 1986, 1989, 2012, 2016, 2020, 2014, 1963,
#        2006, 2021, 2010, 2018, 1977, 2011, 1995, 2019, 1985, 1964, 2015,
#        2009, 2001, 1982, 2008], dtype=int64)

# %% [markdown]
# ## Authors

# %%
authors = pd.json_normalize(df['Authors'])
print("Number of null values in authors: \n First author: {first}\n Second author: {second} \n Third author: {third} \n Fourth author: {fourth}\n Fifth author: {fifth}\n Sixth author: {sixth}".format(first=authors[0].isna().sum(), second= authors[1].isna().sum(), third= authors[2].isna().sum(), fourth= authors[3].isna().sum(), fifth= authors[4].isna().sum(), sixth= authors[5].isna().sum()))
# Out:
# Number of null values in authors:
#  First author: 9
#  Second author: 565
#  Third author: 917
#  Fourth author: 1149
#  Fifth author: 1272
#  Sixth author: 1325

# %%
nested_authors1 = pd.json_normalize(authors[0]).rename(columns={'authorId':'author_1_id', 'name':'author_1_name'})
nested_authors1['index'] = nested_authors1.index
nested_authors1_comb = nested_authors1.groupby(['author_1_id','author_1_name']).size().reset_index().rename(columns={0:'count'})
nested_authors1_comb = nested_authors1_comb.sort_values(by='count', ascending=False)

# Following the same technique from the previous author 1 set
# Author 2
nested_authors2 = pd.json_normalize(authors[1]).rename(columns={'authorId':'author_2_id', 'name':'author_2_name'})
nested_authors2['index'] = nested_authors2.index
nested_authors2_comb = nested_authors2.groupby(['author_2_id','author_2_name']).size().reset_index().rename(columns={0:'count'})
nested_authors2_comb = nested_authors2_comb.sort_values(by='count', ascending=False)

# Author 3
nested_authors3 = pd.json_normalize(authors[2]).rename(columns={'authorId':'author_3_id', 'name':'author_3_name'})
nested_authors3['index'] = nested_authors3.index
nested_authors3_comb = nested_authors3.groupby(['author_3_id','author_3_name']).size().reset_index().rename(columns={0:'count'})
nested_authors3_comb = nested_authors3_comb.sort_values(by='count', ascending=False)

# Author 4
nested_authors4 = pd.json_normalize(authors[3]).rename(columns={'authorId':'author_4_id', 'name':'author_4_name'})
nested_authors4['index'] = nested_authors4.index
nested_authors4_comb = nested_authors4.groupby(['author_4_id','author_4_name']).size().reset_index().rename(columns={0:'count'})
nested_authors4_comb = nested_authors4_comb.sort_values(by='count', ascending=False)

# Author 5
nested_authors5 = pd.json_normalize(authors[4]).rename(columns={'authorId':'author_5_id', 'name':'author_5_name'})
nested_authors5['index'] = nested_authors5.index
nested_authors5_comb = nested_authors5.groupby(['author_5_id','author_5_name']).size().reset_index().rename(columns={0:'count'})
nested_authors5_comb = nested_authors5_comb.sort_values(by='count', ascending=False)

# Author 6
nested_authors6 = pd.json_normalize(authors[5]).rename(columns={'authorId':'author_6_id', 'name':'author_6_name'})
nested_authors6['index'] = nested_authors6.index
nested_authors6_comb = nested_authors6.groupby(['author_6_id','author_6_name']).size().reset_index().rename(columns={0:'count'})
nested_authors6_comb = nested_authors6_comb.sort_values(by='count', ascending=False)

# %%
#only run once
df = pd.merge(df, nested_authors1, on="index")
df = pd.merge(df, nested_authors2, on="index")
df = pd.merge(df, nested_authors3, on="index")
df = pd.merge(df, nested_authors4, on="index")
df = pd.merge(df, nested_authors5, on="index")
df = pd.merge(df, nested_authors6, on="index")

# %%
df = df.drop(columns=['Authors'])

# %% [markdown]
# ## Fields

# %%
fields = df.fieldsOfStudy.copy()

fields = fields.explode()
fields_index = fields.index.to_list()
fields_name = fields.to_list()
fields = [fields_index, fields_name]
fields = pd.DataFrame(fields).transpose()
fields.columns = ['index', 'name']

# unique_fields = list(fields.name.unique()) # Will be useful later

fields = fields.groupby(by='index')['name'].apply(lambda x:x.str.cat(sep=", ")).reset_index(drop=True)
fields = pd.DataFrame(fields)
fields['index'] = fields.index

fields
# Out:
#             name  index
# 0     Psychology      0
# 1      Sociology      1
# 2       Medicine      2
# 3      Sociology      3
# 4     Psychology      4
# ...          ...    ...
# 1398    Medicine   1398
# 1399  Philosophy   1399
# 1400     Physics   1400
# 1401               1401
# 1402    Medicine   1402
#
# [1403 rows x 2 columns]

# %%
# drop the column 'fieldsOfStudy'
df = df.drop(columns=['fieldsOfStudy'])

# merge the above dataframe to this one
df = pd.merge(df, fields, on="index").rename(columns={'name': 'fieldsOfStudy'})

# %% [markdown]
# ## Publication Type

# %%
pub_type = df['Publication_Type'].copy()

pub_type = pub_type.explode()
pub_type_index = pub_type.index.to_list()
pub_type_name = pub_type.to_list()
pub_type = [pub_type_index, pub_type_name]
pub_type = pd.DataFrame(pub_type).transpose()
pub_type.columns = ['index', 'name']

# unique_fields = list(fields.name.unique()) # Will be useful later

pub_type = pub_type.groupby(by='index')['name'].apply(lambda x:x.str.cat(sep=", ")).reset_index(drop=True)
pub_type = pd.DataFrame(pub_type)
pub_type['index'] = pub_type.index

pub_type
# Out:
#                         name  index
# 0                                 0
# 1                                 1
# 2             JournalArticle      2
# 3                                 3
# 4                     Review      4
# ...                      ...    ...
# 1387                           1387
# 1388          JournalArticle   1388
# 1389                           1389
# 1390  JournalArticle, Review   1390
# 1391          JournalArticle   1391
#
# [1392 rows x 2 columns]

# %%
# drop the column 'fieldsOfStudy'
df = df.drop(columns=['Publication_Type'])

# merge the above dataframe to this one
df = pd.merge(df, pub_type, on="index").rename(columns={'name': 'Publication_Type'})

# %%
df.to_csv('collected_elsevier_data.csv')

# %%
df
# Out:
#                                                   Title  \
# 0     The Scale of Ethical Attitude toward Ethnic Hu...
# 1     A Feminist Pentecostal Theological Anthropolog...
# 2     Dying to Get Out of the Asylum: Mortality and ...
# 3     Citizenship without representation? Blackface,...
# 4     Schools, Sex Education, and Support for Sexual...
# ...                                                 ...
# 1376  Body, Eugenics and Nationalism: Women in the F...
# 1377  What Looks Like Sexism and Why? The Effect of ...
# 1378  The Standardized Experimental Situation in Exp...
# 1379  Playing Games and Asking Questions in a Non-WE...
# 1380  The psychometric assessment of human life hist...
#
#                                                Abstract  \
# 0     Research on ethnic humor has been centered on ...
# 1     Abstract In this article I focus on developing...
# 2     This article examines the status of lunatic ca...
# 3     Abstract This article explores Die Antwoord's ...
# 4     School-based adolescent sexual health educatio...
# ...                                                 ...
# 1376  This research analyses images of the female bo...
# 1377  ABSTRACT. Sexist comments are not perceived eq...
# 1378                                               None
# 1379  A recent debate across the social sciences que...
# 1380  A growing body of empirical literature support...
#
#                                     Venue  Year  Reference_Count  \
# 0                                          2013               77
# 1                                          2013                1
# 2     Bulletin of The History of Medicine  2013               74
# 3                                          2013               41
# 4                                          2013               84
# ...                                   ...   ...              ...
# 1376                                       2014               47
# 1377    The Journal of general psychology  2014               45
# 1378                                       2014               79
# 1379                                       2014               34
# 1380                                       2014              170
#
#       Citation_Count  Influential_Citation_Count  Open_Access  \
# 0                  5                           0         True
# 1                  1                           0        False
# 2                  4                           1        False
# 3                  2                           0        False
# 4                 40                           6        False
# ...              ...                         ...          ...
# 1376               2                           0        False
# 1377              24                           4        False
# 1378              39                           3        False
# 1379               0                           0        False
# 1380             115                          10        False
#
#                                                    TLDR  index  ...  \
# 0                                                  None      0  ...
# 1                                                  None      1  ...
# 2     {'model': 'tldr@v2.0.0', 'text': 'Cause of dea...      2  ...
# 3                                                  None      3  ...
# 4                                                  None      4  ...
# ...                                                 ...    ...  ...
# 1376                                               None   1387  ...
# 1377  {'model': 'tldr@v2.0.0', 'text': 'It is demons...   1388  ...
# 1378                                               None   1389  ...
# 1379                                               None   1390  ...
# 1380                                               None   1391  ...
#
#      author_3_id  author_3_name author_4_id author_4_name author_5_id  \
# 0        2001444       G. Pfuhl    34585107    R. Biegler     4994730
# 1            NaN            NaN         NaN           NaN         NaN
# 2     2149888528   Tom Themeles         NaN           NaN         NaN
# 3            NaN            NaN         NaN           NaN         NaN
# 4            NaN            NaN         NaN           NaN         NaN
# ...          ...            ...         ...           ...         ...
# 1376         NaN            NaN         NaN           NaN         NaN
# 1377         NaN            NaN         NaN           NaN         NaN
# 1378   114601026  Mateja Melink         NaN           NaN         NaN
# 1379         NaN            NaN         NaN           NaN         NaN
# 1380         NaN            NaN         NaN           NaN         NaN
#
#      author_5_name author_6_id author_6_name        fieldsOfStudy  \
# 0      A. Teymoori         NaN           NaN           Psychology
# 1              NaN         NaN           NaN            Sociology
# 2              NaN         NaN           NaN             Medicine
# 3              NaN         NaN           NaN            Sociology
# 4              NaN         NaN           NaN           Psychology
# ...            ...         ...           ...                  ...
# 1376           NaN         NaN           NaN            Sociology
# 1377           NaN         NaN           NaN            Sociology
# 1378           NaN         NaN           NaN            Sociology
# 1379           NaN         NaN           NaN  Medicine, Economics
# 1380           NaN         NaN           NaN  Sociology, Medicine
#
#             Publication_Type
# 0
# 1
# 2             JournalArticle
# 3
# 4                     Review
# ...                      ...
# 1376
# 1377          JournalArticle
# 1378
# 1379  JournalArticle, Review
# 1380          JournalArticle
#
# [1381 rows x 24 columns]

# %%
# Create two dataframes based on Computer Science and Social Science

# All computer science and related fields
df_comp = df[df.fieldsOfStudy.str.contains('Computer Science') == True]
df_engg = df[df.fieldsOfStudy.str.contains('Engineering') == True]
df_maths = df[df.fieldsOfStudy.str.contains('Mathematics') == True]
df_comp = pd.concat([df_comp, df_engg, df_maths])
df_comp = df_comp.drop_duplicates(subset=['index']).reset_index(drop=True) #dropping rows with same index values

# All social science and related fields
df_soc = df[df.fieldsOfStudy.str.contains('Sociology') == True]
df_pol = df[df.fieldsOfStudy.str.contains('Political Science') == True]
df_phy = df[df.fieldsOfStudy.str.contains('Philosophy') == True]
df_psc = df[df.fieldsOfStudy.str.contains('Psychology') == True]
df_soc = pd.concat([df_soc, df_pol, df_phy, df_psc])
df_soc = df_soc.drop_duplicates(subset=['index']).reset_index(drop=True) #dropping rows with same index values

# %%
len(df_comp), len(df_soc)
# Out:
# (47, 1055)

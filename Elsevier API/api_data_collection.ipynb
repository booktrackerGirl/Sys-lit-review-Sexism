# %%
import elsapy
from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
import json

import httpx
import time
import requests
import textwrap

import pandas as pd
import numpy as np
import sys

import config

# %% [markdown]
# ### Scopus Search API

# %%
# Specify the keys and tokens

api_key = config.elsevier_api_key
inst_token = config.elsevier_inst_token

# %%
headers = {
        'Accept': 'application/json',
        'X-ELS-APIKey': api_key,
        'X-ELS-Insttoken': inst_token
    }
    
# Actual query: 
# (misogyny OR sexism OR gender violence) AND (detection OR identification OR prediction OR classification)

# https://dev.elsevier.com/sc_search_tips.html
# URL encoding
#The Boolean search is submitted through the query string parameter 'query'. 
# As with all other query string parameters, the contents of the submitted search must be URL-encoded. 
# It should be noted that the '+' character serves a special purpose as a query string value, 
# functioning as an equivalent to the space character (i.e. %20). In order to submit a literal character '+' it must be properly URL-encoded (i.e. %2B).

# query = 'KEY%28misogyny%20OR%20sexism%20OR%20gender%20violence%29%20AND%20%28detection%20OR%20identification%20OR%20prediction%20OR%20classification%29'
# query = 'KEY%28misogyny%20OR%20sexism%29%20AND%20%28detection%20OR%20identification%20OR%20prediction%20OR%20classification%29'
query = 'misogyny%20detection%20OR%20misogyny%20identification%20OR%20misogyny%20prediction%20OR%20misogyny%20classification%20OR%20sexism%20detection%20OR%20sexism%20identification%20OR%20sexism%20prediction%20OR%20sexism%20classification'

# dc:description (Abstract) is not available in Standard type, and the Complete type is not accessible
fields = 'dc:identifier' # just need the scopus ID for the next step
# ,eid,dc:title,dc:creator,prism:aggregationType,subtype,subtypeDescription,citedby-count,prism:publicationName,prism:coverDate,prism:doi,pii,orcid,openaccess,affiliation,author
offset = 0
years = '2012-2023'

# %%
responses = requests.get(f'https://api.elsevier.com/content/search/scopus?query={query}&field={fields}&date={years}', headers=headers, stream = True)
responses
# Out:
# <Response [200]>

# %%
json = responses.json()
json = json['search-results']
json.keys()
# Out:
# dict_keys(['opensearch:totalResults', 'opensearch:startIndex', 'opensearch:itemsPerPage', 'opensearch:Query', 'link', 'entry'])

# %%
json['opensearch:totalResults']
# Out:
# '328'

# %%
json['opensearch:startIndex'], json['opensearch:itemsPerPage'], json['link']
# not that useful
# Out:
# ('0',
#  '25',
#  [{'@_fa': 'true',
#    '@ref': 'self',
#    '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=misogyny+detection+OR+misogyny+identification+OR+misogyny+prediction+OR+misogyny+classification+OR+sexism+detection+OR+sexism+identification+OR+sexism+prediction+OR+sexism+classification&field=dc:identifier&date=2012-2023',
#    '@type': 'application/json'},
#   {'@_fa': 'true',
#    '@ref': 'first',
#    '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=misogyny+detection+OR+misogyny+identification+OR+misogyny+prediction+OR+misogyny+classification+OR+sexism+detection+OR+sexism+identification+OR+sexism+prediction+OR+sexism+classification&field=dc:identifier&date=2012-2023',
#    '@type': 'application/json'},
#   {'@_fa': 'true',
#    '@ref': 'next',
#    '@href': 'https://api.elsevier.com/content/search/scopus?start=25&count=25&query=misogyny+detection+OR+misogyny+identification+OR+misogyny+prediction+OR+misogyny+classification+OR+sexism+detection+OR+sexism+identification+OR+sexism+prediction+OR+sexism+classification&field=dc:identifier&date=2012-2023',
#    '@type': 'application/json'},
#   {'@_fa': 'true',
#    '@ref': 'last',
#    '@href': 'https://api.elsevier.com/content/search/scopus?start=303&count=25&query=misogyny+detection+OR+misogyny+identification+OR+misogyny+prediction+OR+misogyny+classification+OR+sexism+detection+OR+sexism+identification+OR+sexism+prediction+OR+sexism+classification&field=dc:identifier&date=2012-2023',
#    '@type': 'application/json'}])

# %%
json['opensearch:Query']
# Out:
# {'@role': 'request',
#  '@searchTerms': 'misogyny detection OR misogyny identification OR misogyny prediction OR misogyny classification OR sexism detection OR sexism identification OR sexism prediction OR sexism classification',
#  '@startPage': '0'}

# %%
json['entry'][0]
# Out:
# {'@_fa': 'true',
#  'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85145576108',
#  'dc:identifier': 'SCOPUS_ID:85145576108'}

# %% [markdown]
# Now let's use the credentials again to get ALL the results

# %%
headers = {
        'Accept': 'application/json',
        'X-ELS-APIKey': api_key,
        'X-ELS-Insttoken': inst_token
    }

#query = 'KEY%28misogyny%20OR%20sexism%20OR%20gender%20violence%29%20AND%20%28detection%20OR%20identification%20OR%20prediction%20OR%20classification%29'
# query = 'KEY%28misogyny%20OR%20sexism%29%20AND%20%28detection%20OR%20identification%20OR%20prediction%20OR%20classification%29'
#query = 'misogyny%20detection%20OR%20misogyny%20identification%20OR%20misogyny%20prediction%20OR%20misogyny%20classification%20OR%20sexism%20detection%20OR%20sexism%20identification%20OR%20sexism%20prediction%20OR%20sexism%20classification'
#query = 'sexism%20OR%20misogy'

#fields = 'dc:identifier,prism:doi'
#offset = 0
#years = '2012-2023'
#year = 2013

#scopus_search_url = 'https://api.elsevier.com/content/search/scopus?'

# %%
json_data1 = []

query = 'sexism' #'sexism%20OR%20misogy'
fields = 'dc:identifier,prism:doi'
year = 2013

scopus_search_url = 'https://api.elsevier.com/content/search/scopus?'
offset = 0

while True: # As long as the url exists
    # print('Requesting', url)
    # print('Offset', offset)
    # Make the request
    responses = requests.get(f'{scopus_search_url}query={query}&field={fields}&date={year}&start={offset}&view=STANDARD', headers=headers, stream = True)
    json = responses.json()
    if 'search-results' in json:
        json = json['search-results']
        # Check if any values are left
        if 'entry' in json : # The 'entry' key only exists if the request was successful, meaning values are left
            offset = offset + 25
            # If data found, add them to the variable, 
            # add them to the list and move to the next offset
            json_data1.extend(json['entry'])
            time.sleep(2)
        else:
            year += 1
            if year > 2022:
                print(f'Reached {year}, so ending search now')
                break
            else: 
                offset = 0
                responses = requests.get(f'{scopus_search_url}query={query}&field={fields}&date={year}&start={offset}&view=STANDARD', headers=headers, stream = True)
                json = responses.json()
                if 'search-results' in json:
                    json = json['search-results']
                    if 'entry' in json : # The 'entry' key only exists if the request was successful, meaning values are left
                        offset = offset + 25
                        json_data1.extend(json['entry'])
                        time.sleep(2)
                        print(f'Starting {year} now')
                    else:
                        print(f'Reached here')
                        continue
                else:
                    print(f'Reached the year {year}, but no search results')
                    continue
    else:
        print(f'Response 400 Bad request') # check the query for the request then
        break

# %%
# Create a dataframe out of it
df_int = pd.DataFrame(json_data1)
# Remove the papers which do not have a DOI
df_int = df_int[~df_int['prism:doi'].isna()]
# Remove duplicates, based on the DOIs
df_int = df_int.drop_duplicates(subset=['prism:doi']).reset_index(drop=True)
df_int
# Out:
#      @_fa                                          prism:url  \
# 0    true  https://api.elsevier.com/content/abstract/scop...
# 1    true  https://api.elsevier.com/content/abstract/scop...
# 2    true  https://api.elsevier.com/content/abstract/scop...
# 3    true  https://api.elsevier.com/content/abstract/scop...
# 4    true  https://api.elsevier.com/content/abstract/scop...
# ..    ...                                                ...
# 185  true  https://api.elsevier.com/content/abstract/scop...
# 186  true  https://api.elsevier.com/content/abstract/scop...
# 187  true  https://api.elsevier.com/content/abstract/scop...
# 188  true  https://api.elsevier.com/content/abstract/scop...
# 189  true  https://api.elsevier.com/content/abstract/scop...
#
#              dc:identifier                                  prism:doi
# 0    SCOPUS_ID:84880475988  10.1093/acprof:oso/9780199892631.001.0001
# 1    SCOPUS_ID:85123129625                   10.4324/9780203143308-13
# 2    SCOPUS_ID:85086983428                    10.4324/9780203094020-9
# 3    SCOPUS_ID:84918877738                      10.4324/9780203143308
# 4    SCOPUS_ID:84882725830                           10.1037/a0028437
# ..                     ...                                        ...
# 185  SCOPUS_ID:85120923782              10.1080/17539153.2021.2005099
# 186  SCOPUS_ID:85113770445                 10.1007/s10508-021-02100-x
# 187  SCOPUS_ID:85106513940                 10.1007/s12559-021-09862-5
# 188  SCOPUS_ID:85102677351              10.1080/09589236.2021.1881461
# 189  SCOPUS_ID:85101092143                 10.1007/s12559-021-09845-6
#
# [190 rows x 4 columns]

# %% [markdown]
# Collecting only the scopus IDs so that it can be used for abstract retrieval.

# %%
scopus_ids = df_int['dc:identifier'].to_list()

# %%
df_int.columns
# Out:
# Index(['@_fa', 'prism:url', 'dc:identifier', 'prism:doi'], dtype='object')

# %% [markdown]
# ### Abstract API
# Use the previous information to retrieve the data from all scopus IDs.

# %%
json_data2 = []
i = 0

for id in scopus_ids: # As long as the url exists
    print(f'ID number {i}: {id}')
    i += 1
    # Make the request
    responses = requests.get(f'https://api.elsevier.com/content/abstract/scopus_id/{id}', headers=headers, stream = True)
    json = responses.json()
    if 'abstracts-retrieval-response' in json:
        json = json['abstracts-retrieval-response']
        # If data found, add them to the variable, 
        # add them to the list and move to the next offset
        json_data2.append(json['coredata'])
        time.sleep(3)
    else:
        continue
# Out:
# ID number 0: SCOPUS_ID:84891790307
# ID number 1: SCOPUS_ID:84890960118
# ID number 2: SCOPUS_ID:84890949474
# ID number 3: SCOPUS_ID:84890926326
# ID number 4: SCOPUS_ID:84890779280
# ID number 5: SCOPUS_ID:84890729284
# ID number 6: SCOPUS_ID:84891020454
# ID number 7: SCOPUS_ID:84890618613
# ID number 8: SCOPUS_ID:84890453114
# ID number 9: SCOPUS_ID:84908664146
# ID number 10: SCOPUS_ID:84890952198
# ID number 11: SCOPUS_ID:84890418819
# ID number 12: SCOPUS_ID:84890346350
# ID number 13: SCOPUS_ID:85069326394
# ID number 14: SCOPUS_ID:85066058738
# ID number 15: SCOPUS_ID:85065460170
# ID number 16: SCOPUS_ID:84890023104
# ID number 17: SCOPUS_ID:84890011380
# ID number 18: SCOPUS_ID:84890349143
# ID number 19: SCOPUS_ID:84890339620
# ID number 20: SCOPUS_ID:84889663603
# ID number 21: SCOPUS_ID:84889054894
# ID number 22: SCOPUS_ID:84889040917
# ID number 23: SCOPUS_ID:84889039446
# ID number 24: SCOPUS_ID:84889004816
# ID number 25: SCOPUS_ID:84889048382
# ID number 26: SCOPUS_ID:85069615715
# ID number 27: SCOPUS_ID:85120164666
# ID number 28: SCOPUS_ID:85074339506
# ID number 29: SCOPUS_ID:84983319996
# ID number 30: SCOPUS_ID:84906648544
# ID number 31: SCOPUS_ID:84906480516
# ID number 32: SCOPUS_ID:84906412509
# ID number 33: SCOPUS_ID:84906210132
# ID number 34: SCOPUS_ID:84906179460
# ID number 35: SCOPUS_ID:84906150068
# ID number 36: SCOPUS_ID:84906058835
# ID number 37: SCOPUS_ID:84906028708
# ID number 38: SCOPUS_ID:84906012633
# ID number 39: SCOPUS_ID:84905960291
# ID number 40: SCOPUS_ID:84905875047
# ID number 41: SCOPUS_ID:84905800059
# ID number 42: SCOPUS_ID:84905779013
# ID number 43: SCOPUS_ID:84905762090
# ID number 44: SCOPUS_ID:84905550831
# ID number 45: SCOPUS_ID:84905520759
# ID number 46: SCOPUS_ID:84905137493
# ID number 47: SCOPUS_ID:84905072729
# ID number 48: SCOPUS_ID:84905068405
# ID number 49: SCOPUS_ID:84905062320
# ID number 50: SCOPUS_ID:84904946960
# ID number 51: SCOPUS_ID:84904941793
# ID number 52: SCOPUS_ID:84904938373
# ID number 53: SCOPUS_ID:84904929011
# ID number 54: SCOPUS_ID:84904927062
# ID number 55: SCOPUS_ID:84904442488
# ID number 56: SCOPUS_ID:84898243890
# ID number 57: SCOPUS_ID:84896865319
# ID number 58: SCOPUS_ID:84896793771
# ID number 59: SCOPUS_ID:84894502912
# ID number 60: SCOPUS_ID:84894291769
# ID number 61: SCOPUS_ID:84894253476
# ID number 62: SCOPUS_ID:84894104321
# ID number 63: SCOPUS_ID:84893599129
# ID number 64: SCOPUS_ID:84893595896
# ID number 65: SCOPUS_ID:84893573382
# ID number 66: SCOPUS_ID:84893535412
# ID number 67: SCOPUS_ID:84893433171
# ID number 68: SCOPUS_ID:84893430807
# ID number 69: SCOPUS_ID:84893271831
# ID number 70: SCOPUS_ID:84893095582
# ID number 71: SCOPUS_ID:84893016553
# ID number 72: SCOPUS_ID:84893000301
# ID number 73: SCOPUS_ID:84892872401
# ID number 74: SCOPUS_ID:84892869594
# ID number 75: SCOPUS_ID:84892756072
# ID number 76: SCOPUS_ID:84892740129
# ID number 77: SCOPUS_ID:84892645989
# ID number 78: SCOPUS_ID:84892393803
# ID number 79: SCOPUS_ID:84892370090
# ID number 80: SCOPUS_ID:84892364594
# ID number 81: SCOPUS_ID:84891703116
# ID number 82: SCOPUS_ID:84891388333
# ID number 83: SCOPUS_ID:84891369503
# ID number 84: SCOPUS_ID:84891311121
# ID number 85: SCOPUS_ID:84890742025
# ID number 86: SCOPUS_ID:84890569285
# ID number 87: SCOPUS_ID:84890554470
# ID number 88: SCOPUS_ID:84890434298
# ID number 89: SCOPUS_ID:84890425315
# ID number 90: SCOPUS_ID:84890192520
# ID number 91: SCOPUS_ID:84890185563
# ID number 92: SCOPUS_ID:84890174409
# ID number 93: SCOPUS_ID:84890143934
# ID number 94: SCOPUS_ID:84890134272
# ID number 95: SCOPUS_ID:84890033220
# ID number 96: SCOPUS_ID:84889645683
# ID number 97: SCOPUS_ID:84889633938
# ID number 98: SCOPUS_ID:84889563754
# ID number 99: SCOPUS_ID:84889249874
# ID number 100: SCOPUS_ID:84888865105
# ID number 101: SCOPUS_ID:84888581344
# ID number 102: SCOPUS_ID:84888378028
# ID number 103: SCOPUS_ID:84888074935
# ID number 104: SCOPUS_ID:84888065591
# ID number 105: SCOPUS_ID:84888062471
# ID number 106: SCOPUS_ID:84888060639
# ID number 107: SCOPUS_ID:84888049899
# ID number 108: SCOPUS_ID:84888045483
# ID number 109: SCOPUS_ID:84888039447
# ID number 110: SCOPUS_ID:84888038662
# ID number 111: SCOPUS_ID:84888005973
# ID number 112: SCOPUS_ID:84887841799
# ID number 113: SCOPUS_ID:84887616721
# ID number 114: SCOPUS_ID:84887612829
# ID number 115: SCOPUS_ID:84887607892
# ID number 116: SCOPUS_ID:84887595316
# ID number 117: SCOPUS_ID:84887590203
# ID number 118: SCOPUS_ID:84887576621
# ID number 119: SCOPUS_ID:84887572065
# ID number 120: SCOPUS_ID:84887525498
# ID number 121: SCOPUS_ID:84887524476
# ID number 122: SCOPUS_ID:84887520866
# ID number 123: SCOPUS_ID:84887446460
# ID number 124: SCOPUS_ID:84887375565
# ID number 125: SCOPUS_ID:84887318377
# ID number 126: SCOPUS_ID:84887317922
# ID number 127: SCOPUS_ID:84887285306
# ID number 128: SCOPUS_ID:84887204319
# ID number 129: SCOPUS_ID:84887192169
# ID number 130: SCOPUS_ID:84886750876
# ID number 131: SCOPUS_ID:84886746581
# ID number 132: SCOPUS_ID:84886594218
# ID number 133: SCOPUS_ID:84886460645
# ID number 134: SCOPUS_ID:84886413166
# ID number 135: SCOPUS_ID:84886101571
# ID number 136: SCOPUS_ID:84886095085
# ID number 137: SCOPUS_ID:84885912301
# ID number 138: SCOPUS_ID:84885594699
# ID number 139: SCOPUS_ID:84885379798
# ID number 140: SCOPUS_ID:84885061373
# ID number 141: SCOPUS_ID:84885031748
# ID number 142: SCOPUS_ID:84884498543
# ID number 143: SCOPUS_ID:84881191496
# ID number 144: SCOPUS_ID:84879539776
# ID number 145: SCOPUS_ID:84870708473
# ID number 146: SCOPUS_ID:71549159116
# ID number 147: SCOPUS_ID:0010621851
# ID number 148: SCOPUS_ID:84956787530
# ID number 149: SCOPUS_ID:84899626073
# ID number 150: SCOPUS_ID:84888269260
# ID number 151: SCOPUS_ID:84888259832
# ID number 152: SCOPUS_ID:84888258720
# ID number 153: SCOPUS_ID:84888224593
# ID number 154: SCOPUS_ID:85018215664
# ID number 155: SCOPUS_ID:84888322794
# ID number 156: SCOPUS_ID:85065939753
# ID number 157: SCOPUS_ID:84887954828
# ID number 158: SCOPUS_ID:84887952663
# ID number 159: SCOPUS_ID:84887911573
# ID number 160: SCOPUS_ID:84887862196
# ID number 161: SCOPUS_ID:84884318378
# ID number 162: SCOPUS_ID:85006665831
# ID number 163: SCOPUS_ID:84887737828
# ID number 164: SCOPUS_ID:85069942220
# ID number 165: SCOPUS_ID:84887545702
# ID number 166: SCOPUS_ID:84926406197
# ID number 167: SCOPUS_ID:84926401546
# ID number 168: SCOPUS_ID:84887480036
# ID number 169: SCOPUS_ID:84887435238
# ID number 170: SCOPUS_ID:84887276723
# ID number 171: SCOPUS_ID:85066059802
# ID number 172: SCOPUS_ID:85029638256
# ID number 173: SCOPUS_ID:84890433425
# ID number 174: SCOPUS_ID:84893012549
# ID number 175: SCOPUS_ID:84910087663
# ID number 176: SCOPUS_ID:84886869611
# ID number 177: SCOPUS_ID:84886857035
# ID number 178: SCOPUS_ID:84886818289
# ID number 179: SCOPUS_ID:85014526239
# ID number 180: SCOPUS_ID:84927561209
# ID number 181: SCOPUS_ID:84886775538
# ID number 182: SCOPUS_ID:85068542915
# ID number 183: SCOPUS_ID:84886652832
# ID number 184: SCOPUS_ID:84885442692
# ID number 185: SCOPUS_ID:85027925777
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~/yes/envs/mlp/lib/python3.8/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/yes/envs/mlp/lib/python3.8/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File ~/yes/envs/mlp/lib/python3.8/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/yes/envs/mlp/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/packages/six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~/yes/envs/mlp/lib/python3.8/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/yes/envs/mlp/lib/python3.8/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File ~/yes/envs/mlp/lib/python3.8/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[29], line 8
#       6 i += 1
#       7 # Make the request
# ----> 8 responses = requests.get(f'https://api.elsevier.com/content/abstract/scopus_id/{id}', headers=headers, stream = True)
#       9 json = responses.json()
#      10 if 'abstracts-retrieval-response' in json:
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/requests/adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     544             raise
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#     550     if isinstance(e.reason, ConnectTimeoutError):
#     551         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
df = pd.DataFrame(json_data2)
df['index'] = df.index
df
# Out:
#     srctype                 eid  \
# 0         j  2-s2.0-85145576108
# 1         j  2-s2.0-85145658852
# 2         j  2-s2.0-85144423009
# 3         j  2-s2.0-85112315917
# 4         j  2-s2.0-85144391539
# ..      ...                 ...
# 316       b  2-s2.0-84901166940
# 317       b  2-s2.0-84900958138
# 318       b  2-s2.0-84945564557
# 319       b  2-s2.0-84872477278
# 320       b  2-s2.0-84925710838
#
#                                         dc:description prism:coverDate  \
# 0    © 2022 Elsevier LtdThe spread of Hate Speech o...      2023-04-01
# 1    © 2022 Elsevier B.V.The enormous growth of soc...      2023-03-01
# 2    © 2022 Elsevier LtdDetecting suicidal tendenci...      2023-03-01
# 3    © 2021, The Author(s).Abusive language is an i...      2023-02-01
# 4    © 2022 Elsevier B.V.As the number of non-nativ...      2023-01-25
# ..                                                 ...             ...
# 316  Argues that South Africa's apartheid system of...      2012-12-01
# 317  In Russia during the second half of the eighte...      2012-12-01
# 318  © 2012 - John Benjamins B.V.This comprehensive...      2012-09-11
# 319  © 2012 by Oxford University Press, Inc. All ri...      2012-05-24
# 320  © 2005 by Lawrence Erlbaum Associates, Inc.Thi...      2012-01-01
#
#     prism:aggregationType                                          prism:url  \
# 0                 Journal  https://api.elsevier.com/content/abstract/scop...
# 1                 Journal  https://api.elsevier.com/content/abstract/scop...
# 2                 Journal  https://api.elsevier.com/content/abstract/scop...
# 3                 Journal  https://api.elsevier.com/content/abstract/scop...
# 4                 Journal  https://api.elsevier.com/content/abstract/scop...
# ..                    ...                                                ...
# 316                  Book  https://api.elsevier.com/content/abstract/scop...
# 317                  Book  https://api.elsevier.com/content/abstract/scop...
# 318                  Book  https://api.elsevier.com/content/abstract/scop...
# 319                  Book  https://api.elsevier.com/content/abstract/scop...
# 320                  Book  https://api.elsevier.com/content/abstract/scop...
#
#     subtypeDescription                                         dc:creator  \
# 0              Article  {'author': [{'ce:given-name': 'Hiren', 'prefer...
# 1               Review  {'author': [{'ce:given-name': 'Sneha', 'prefer...
# 2              Article  {'author': [{'ce:given-name': 'Soumitra', 'pre...
# 3              Article  {'author': [{'ce:given-name': 'Endang Wahyu', ...
# 4              Article  {'author': [{'ce:given-name': 'Soumitra', 'pre...
# ..                 ...                                                ...
# 316               Book  {'author': [{'ce:given-name': 'Amanda Lock', '...
# 317               Book  {'author': [{'ce:given-name': 'Anna', 'preferr...
# 318               Book  {'author': [{'ce:given-name': 'Heiko', 'prefer...
# 319               Book  {'author': [{'ce:given-name': 'Lucy Valerie', ...
# 320               Book  {'author': [{'ce:given-name': 'Wendy', 'prefer...
#
#                                                   link  \
# 0    [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# 1    [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# 2    [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# 3    [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# 4    [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# ..                                                 ...
# 316  [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# 317  [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# 318  [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# 319  [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
# 320  [{'@_fa': 'true', '@rel': 'self', '@href': 'ht...
#
#                                  prism:publicationName  ... article-number  \
# 0                     Expert Systems with Applications  ...         119342
# 1                              Entertainment Computing  ...         100544
# 2                Information Processing and Management  ...         103234
# 3                    Personal and Ubiquitous Computing  ...            NaN
# 4                              Knowledge-Based Systems  ...         110182
# ..                                                 ...  ...            ...
# 316  Sex in Transition: Remaking Gender and Race in...  ...            NaN
# 317  From the Womb to the Body Politic: Raising the...  ...            NaN
# 318  An Interdisciplinary Bibliography on Language,...  ...            NaN
# 319  State of Peril: Race and Rape in South African...  ...            NaN
# 320      Women, Madness and the Law: A Feminist Reader  ...            NaN
#
#              dc:identifier                                       dc:publisher  \
# 0    SCOPUS_ID:85145576108                                       Elsevier Ltd
# 1    SCOPUS_ID:85145658852                                      Elsevier B.V.
# 2    SCOPUS_ID:85144423009                                       Elsevier Ltd
# 3    SCOPUS_ID:85112315917  Springer Science and Business Media Deutschlan...
# 4    SCOPUS_ID:85144391539                                      Elsevier B.V.
# ..                     ...                                                ...
# 316  SCOPUS_ID:84901166940                 State University of New York Press
# 317  SCOPUS_ID:84900958138                      University of Wisconsin Press
# 318  SCOPUS_ID:84945564557                  John Benjamins Publishing Company
# 319  SCOPUS_ID:84872477278                            Oxford University Press
# 320  SCOPUS_ID:84925710838                                 Taylor and Francis
#
#     prism:issueIdentifier prism:pageRange prism:endingPage prism:startingPage  \
# 0                     NaN             NaN              NaN                NaN
# 1                     NaN             NaN              NaN                NaN
# 2                       2             NaN              NaN                NaN
# 3                       1           17-43               43                 17
# 4                     NaN             NaN              NaN                NaN
# ..                    ...             ...              ...                ...
# 316                   NaN           1-329              329                  1
# 317                   NaN           1-228              228                  1
# 318                   NaN           1-294              294                  1
# 319                   NaN           1-272              272                  1
# 320                   NaN           1-301              301                  1
#
#     pubmed-id                                        prism:isbn index
# 0         NaN                                               NaN     0
# 1         NaN                                               NaN     1
# 2         NaN                                               NaN     2
# 3         NaN                                               NaN     3
# 4         NaN                                               NaN     4
# ..        ...                                               ...   ...
# 316       NaN                                     9781438444079   316
# 317       NaN     [{'$': '029928994X'}, {'$': '9780299289942'}]   317
# 318       NaN  [{'$': '9789027273154'}, {'$': '9789027212009'}]   318
# 319       NaN  [{'$': '9780199933327'}, {'$': '9780199796373'}]   319
# 320       NaN                                     9781843146063   320
#
# [321 rows x 30 columns]

# %%
df['dc:description'][1]
# Some of the abstracts have the copyright and author's name in the abstract. It needs to be removed.
# Out:
# '© 2022 Elsevier B.V.The enormous growth of social media provides a platform for displaying harmful, offensive online behaviour, which keeps increasing with time. The popularity of smartphones and the anonymity of the internet have made online offensive behaviour very common. Therefore, research on social media offensive behaviour has increased in recent years. In this paper, we have endeavoured to depict the variety of abusive behaviour one can encounter online and the significance of detecting them by classifying them into four categories: Content-Based, Sentiment and Emotion Based, User or Profile Based, and Network or Graph-Based approach. We review the state-of-the-art methods to detect bullies and abusive content on social media and discuss the factors that drive offenders to indulge in offensive activity, preventive actions to avoid online toxicity, and various cyber laws in different countries. Finally, we identify and discuss the future research directions that serve as a reference to overcome offensive content in social media.'

# %%
df['dc:description'][0]
# Out:
# '© 2022 Elsevier LtdThe spread of Hate Speech on online platforms is a severe issue for societies and requires the identification of offensive content by platforms. Research has modeled Hate Speech recognition as a text classification problem that predicts the class of a message based on the text of the message only. However, context plays a huge role in communication. In particular, for short messages, the text of the preceding tweets can completely change the interpretation of a message within a discourse. This work extends previous efforts to classify Hate Speech by considering the current and previous tweets jointly. In particular, we introduce a clearly defined way of extracting context. We present the development of the first dataset for conversational-based Hate Speech classification with an approach for collecting context from long conversations for code-mixed Hindi (ICHCL dataset). Overall, our benchmark experiments show that the inclusion of context can improve classification performance over a baseline. Furthermore, we develop a novel processing pipeline for processing the context. The best-performing pipeline uses a fine-tuned SentBERT paired with an LSTM as a classifier. This pipeline achieves a macro F1 score of 0.892 on the ICHCL test dataset. Another KNN, SentBERT, and ABC weighting-based pipeline yields an F1 Macro of 0.807, which gives the best results among traditional classifiers. So even a KNN model gives better results with an optimized BERT than a vanilla BERT model.'

# %%
df['dc:description'][2]
# Out:
# "© 2022 Elsevier LtdDetecting suicidal tendencies and preventing suicides is an important social goal. The rise and continuance of emotion, the emotion category, and the intensity of the emotion are important clues about suicidal tendencies. The three determinants of emotion, viz. Valence, Arousal, and Dominance (VAD) can help determine a person's exact emotion(s) and its intensity. This paper introduces an end-to-end VAD-assisted transformer-based multi-task network for detecting emotion (primary task) and its intensity (auxiliary task) in suicide notes. As part of this research, we expand the utility of the emotion-annotated benchmark dataset of suicide notes, CEASE-v2.0, by annotating all its sentences with emotion intensity labels. Empirical results show that our multi-task method performs better than the corresponding single-task systems, with the best attained overall Mean Recall (MR) of 65.25% on the emotion task. On a similar task, we improved MR by 8.78% over the existing state-of-the-art system. We evaluated our approach on three benchmark datasets for three different tasks. We observed that the introduced method consistently outperformed existing state-of-the-art approaches on the studied datasets, demonstrating its capacity to generalize to other downstream correlated tasks. We qualitatively examined our model's output by comparing it to the labeling of a psychiatrist."

# %%
df['prism:doi'].isna().sum() # Only a handful of them do not have a DOI
# Out:
# 121

# %%
df.subtypeDescription.unique()
# Out:
# array(['Article', 'Review', 'Data Paper', 'Conference Paper', 'Book',
#        'Book Chapter', 'Conference Review'], dtype=object)

# %%
df['prism:aggregationType'].unique()
# Out:
# array(['Journal', 'Conference Proceeding', 'Book', 'Book Series'],
#       dtype=object)

# %%
df['dc:creator']
# Out:
# 0      {'author': [{'ce:given-name': 'Hiren', 'prefer...
# 1      {'author': [{'ce:given-name': 'Sneha', 'prefer...
# 2      {'author': [{'ce:given-name': 'Soumitra', 'pre...
# 3      {'author': [{'ce:given-name': 'Endang Wahyu', ...
# 4      {'author': [{'ce:given-name': 'Soumitra', 'pre...
#                              ...
# 316    {'author': [{'ce:given-name': 'Amanda Lock', '...
# 317    {'author': [{'ce:given-name': 'Anna', 'preferr...
# 318    {'author': [{'ce:given-name': 'Heiko', 'prefer...
# 319    {'author': [{'ce:given-name': 'Lucy Valerie', ...
# 320    {'author': [{'ce:given-name': 'Wendy', 'prefer...
# Name: dc:creator, Length: 321, dtype: object

# %% [markdown]
# Make a list of the DOIs which would help in extracting the abstracts of the articles.

# %% [markdown]
# But first join the two dataframes, so that it could be used as a single dataframe.

# %%
df.columns
# Out:
# Index(['srctype', 'eid', 'dc:description', 'prism:coverDate',
#        'prism:aggregationType', 'prism:url', 'subtypeDescription',
#        'dc:creator', 'link', 'prism:publicationName', 'source-id', 'pii',
#        'citedby-count', 'prism:volume', 'subtype', 'dc:title', 'openaccess',
#        'openaccessFlag', 'prism:doi', 'prism:issn', 'article-number',
#        'dc:identifier', 'dc:publisher', 'prism:issueIdentifier',
#        'prism:pageRange', 'prism:endingPage', 'prism:startingPage',
#        'pubmed-id', 'prism:isbn', 'index'],
#       dtype='object')

# %%
# Only take the dois which do not have null values
doi_ids = df['prism:doi'][~df['prism:doi'].isna()].to_list() 
len(doi_ids)
# Out:
# 200

# %%
df['dc:creator'][0]
# Out:
# {'author': [{'ce:given-name': 'Hiren',
#    'preferred-name': {'ce:given-name': 'Hiren',
#     'ce:initials': 'H.',
#     'ce:surname': 'Madhu',
#     'ce:indexed-name': 'Madhu H.'},
#    '@seq': '1',
#    'ce:initials': 'H.',
#    '@_fa': 'true',
#    'affiliation': [{'@id': '60014097',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60014097'},
#     {'@id': '125175992',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/125175992'}],
#    'ce:surname': 'Madhu',
#    '@auid': '57222510587',
#    'author-url': 'https://api.elsevier.com/content/author/author_id/57222510587',
#    'ce:indexed-name': 'Madhu H.'}]}

# %%
df_creator = pd.json_normalize(df['dc:creator'])
df_creator['index'] = df_creator.index
df_creator['author'] = pd.json_normalize(df_creator['author'])
df_creator['author'][22]
# Out:
# {'ce:given-name': 'Ignacio',
#  '@seq': '1',
#  'ce:initials': 'I.',
#  '@_fa': 'true',
#  'ce:surname': 'Blanco-Alfonso',
#  '@auid': '57214097368',
#  'author-url': 'https://api.elsevier.com/content/author/author_id/57214097368',
#  'ce:indexed-name': 'Blanco-Alfonso I.',
#  'preferred-name.ce:given-name': 'Ignacio',
#  'preferred-name.ce:initials': 'I.',
#  'preferred-name.ce:surname': 'Blanco-Alfonso',
#  'preferred-name.ce:indexed-name': 'Blanco-Alfonso I.',
#  'affiliation.@id': '60014037',
#  'affiliation.@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60014037'}

# %% [markdown]
# After trying the authors, it seems that this API only gives information about the first author. This is why Semantic Scholar API could be used alongside this to extract the information on the co-authors.

# %% [markdown]
# ### Semantic API
# Since the primary keys are different, use the DOIs of the manuscripts to search for them through the Semantic Scholar API.

# %%
semantic_api_key = config.semantic_api_key

headers = {
        'Content-type': 'application/json',
        'x-api-key': semantic_api_key
    }

# %% [markdown]
# #### Details about the paper based on Paper ID

# %%
fields = 'title,abstract,authors,venue,publicationVenue,year,referenceCount,influentialCitationCount,fieldsOfStudy,tldr'

# %%
json_data3 = []
i = 0

for id in doi_ids: # As long as the url exists
    print(f'ID number {i}: {id}')
    i += 1

    # Make the request to get the paper ID which is needed for the next step
    responses = requests.get(f'https://api.semanticscholar.org/graph/v1/paper/{id}', headers=headers, stream = True)
    json = responses.json()
    # Check if 'paperId' is there in the json file
    if 'paperId' in json:
        paper_id = json['paperId']

        # make the second request to get the details of the paper 
        response = requests.get(f'https://api.semanticscholar.org/graph/v1/paper/{paper_id}?fields={fields}', headers=headers, stream = True)
        json = response.json()
        json_data3.append(json)
        time.sleep(3)

    else: # if the request does not fetch anything
        continue
# Out:
# ID number 0: 10.1016/j.eswa.2022.119342
# ID number 1: 10.1016/j.entcom.2022.100544
# ID number 2: 10.1016/j.ipm.2022.103234
# ID number 3: 10.1007/s00779-021-01609-1
# ID number 4: 10.1016/j.knosys.2022.110182
# ID number 5: 10.1016/j.ipm.2022.103118
# ID number 6: 10.32604/cmc.2023.032993
# ID number 7: 10.1080/00224499.2022.2103071
# ID number 8: 10.1177/09579265221099380
# ID number 9: 10.1177/08862605221084747
# ID number 10: 10.1016/j.knosys.2022.109965
# ID number 11: 10.1007/s13278-022-00993-7
# ID number 12: 10.1007/s13278-022-00940-6
# ID number 13: 10.1145/3555618
# ID number 14: 10.1016/j.jjimei.2022.100119
# ID number 15: 10.1145/3549498
# ID number 16: 10.1371/journal.pone.0274317
# ID number 17: 10.1016/j.dib.2022.108526
# ID number 18: 10.1016/j.engappai.2022.105283
# ID number 19: 10.1145/3551349.3559571
# ID number 20: 10.1145/3551349.3559515
# ID number 21: 10.23940/ijpe.22.09.p8.668678
# ID number 22: 10.26441/RC21.2-2022-A2
# ID number 23: 10.26342/2022-69-19
# ID number 24: 10.26342/2022-69-20
# ID number 25: 10.1016/j.jag.2022.102967
# ID number 26: 10.1016/j.array.2022.100217
# ID number 27: 10.1016/j.eswa.2022.117032
# ID number 28: 10.1007/s10612-021-09604-x
# ID number 29: 10.3366/cor.2022.0255
# ID number 30: 10.1177/21533687221101793
# ID number 31: 10.1007/s11263-022-01625-5
# ID number 32: 10.1016/j.osnem.2022.100210
# ID number 33: 10.5755/j01.itc.51.2.29988
# ID number 34: 10.1145/3530901
# ID number 35: 10.3390/info13060273
# ID number 36: 10.1145/3487061
# ID number 37: 10.1016/j.comcom.2022.03.021
# ID number 38: 10.1016/j.future.2021.12.011
# ID number 39: 10.1177/0886260520967143
# ID number 40: 10.1007/s40747-021-00625-1
# ID number 41: 10.1007/s10586-021-03483-1
# ID number 42: 10.3390/math10060945
# ID number 43: 10.1145/3488560.3501392
# ID number 44: 10.6018/reifop.533411
# ID number 45: 10.1109/ICOIACT55506.2022.9972171
# ID number 46: 10.47750/pnr.2022.13.S03.072
# ID number 47: 10.1007/s10508-022-02502-5
# ID number 48: 10.4324/9781003081388
# ID number 49: 10.4324/9781003195542
# ID number 50: 10.1108/GM-01-2021-0026
# ID number 51: 10.1007/978-3-031-16270-1_21
# ID number 52: 10.21512/commit.v16i2.8343
# ID number 53: 10.1007/978-3-031-08421-8_19
# ID number 54: 10.1007/s40747-022-00693-x
# ID number 55: 10.4324/9780429291975
# ID number 56: 10.1037/sgd0000574
# ID number 57: 10.1155/2022/7937667
# ID number 58: 10.7717/PEERJ-CS.906
# ID number 59: 10.1080/14680777.2022.2047089
# ID number 60: 10.1007/s10579-022-09582-8
# ID number 61: 10.1145/3457610
# ID number 62: 10.1109/ACCESS.2022.3147588
# ID number 63: 10.1109/ACCESS.2022.3140342
# ID number 64: 10.1016/j.osnem.2021.100182
# ID number 65: 10.1080/17539153.2021.2005099
# ID number 66: 10.1007/s10508-021-02100-x
# ID number 67: 10.1007/s12559-021-09862-5
# ID number 68: 10.1080/09589236.2021.1881461
# ID number 69: 10.1007/s12559-021-09845-6
# ID number 70: 10.1016/j.eswa.2021.115632
# ID number 71: 10.1145/3503162.3503168
# ID number 72: 10.1007/s41019-021-00168-y
# ID number 73: 10.1111/sjop.12763
# ID number 74: 10.1007/s10579-021-09530-y
# ID number 75: 10.1371/journal.pone.0243300
# ID number 76: 10.1145/3501774.3501797
# ID number 77: 10.1145/3487351.3488342
# ID number 78: 10.3390/app112210801
# ID number 79: 10.1145/3475716.3484189
# ID number 80: 10.1332/239868021X16286662118554
# ID number 81: 10.3145/epi.2021.sep.02
# ID number 82: 10.1371/journal.pone.0257903
# ID number 83: 10.26342/2021-67-17
# ID number 84: 10.1016/j.ipm.2021.102643
# ID number 85: 10.1515/jso-2021-0033
# ID number 86: 10.1016/j.eswa.2021.114802
# ID number 87: 10.1613/JAIR.1.12590
# ID number 88: 10.1145/3457189
# ID number 89: 10.1145/3447535.3462502
# ID number 90: 10.1016/j.ipm.2021.102524
# ID number 91: 10.3390/math9080807
# ID number 92: 10.1177/1464700120988643
# ID number 93: 10.1016/j.eswa.2020.114120
# ID number 94: 10.26342/2021-66-5
# ID number 95: 10.1177/0956797620968529
# ID number 96: 10.1038/s41443-020-0302-0
# ID number 97: 10.1080/08164649.2022.2062669
# ID number 98: 10.1109/CogMI52975.2021.00014
# ID number 99: 10.1109/SNAMS53716.2021.9732077
# ID number 100: 10.1007/s40747-021-00561-0
# ID number 101: 10.1109/ICMLA52953.2021.00253
# ID number 102: 10.1109/BigData52589.2021.9671478
# ID number 103: 10.1109/BigData52589.2021.9671823
# ID number 104: 10.1109/BigData52589.2021.9672065
# ID number 105: 10.1109/SMC52423.2021.9659158
# ID number 106: 10.7203/QF.0.21982
# ID number 107: 10.1525/luminos.110
# ID number 108: 10.1007/978-3-030-81462-5_46
# ID number 109: 10.1109/ACCESS.2021.3103459
# ID number 110: 10.1109/ACCESS.2021.3103697
# ID number 111: 10.1177/20563051211036939
# ID number 112: 10.7717/peerj-cs.559
# ID number 113: 10.7717/PEERJ-CS.598
# ID number 114: 10.1080/21670811.2021.1882868
# ID number 115: 10.1108/QRJ-09-2020-0108
# ID number 116: 10.1007/978-981-16-0401-0_26
# ID number 117: 10.1080/14442213.2021.1882548
# ID number 118: 10.3390/electronics10010005
# ID number 119: 10.1080/09589236.2020.1834368
# ID number 120: 10.1016/j.future.2020.08.032
# ID number 121: 10.4018/978-1-7998-3763-3
# ID number 122: 10.1109/CSCI51800.2020.00051
# ID number 123: 10.1016/j.ipm.2020.102360
# ID number 124: 10.1145/3340531.3412764
# ID number 125: 10.1080/14680777.2019.1643387
# ID number 126: 10.26342/2020-65-13
# ID number 127: 10.1086/709362
# ID number 128: 10.3390/PUBLICATIONS8030041
# ID number 129: 10.1177/0038026120934690
# ID number 130: 10.1145/3369869
# ID number 131: 10.1145/3313831.3376645
# ID number 132: 10.1080/1369118X.2020.1713843
# ID number 133: 10.14361/9783839451540
# ID number 134: 10.1016/j.bodyim.2020.01.006
# ID number 135: 10.1016/j.cose.2019.101710
# ID number 136: 10.1080/13572334.2020.1730502
# ID number 137: 10.1109/ACCESS.2020.3042604
# ID number 138: 10.4324/9781003037965
# ID number 139: 10.1093/oso/9780190084448.001.0001
# ID number 140: 10.1007/978-3-030-62008-0_37
# ID number 141: 10.1007/978-3-030-62015-8_4
# ID number 142: 10.1007/978-3-030-62015-8_3
# ID number 143: 10.5771/1615-634X-2020-3-211
# ID number 144: 10.1891/VV-D-18-00159
# ID number 145: 10.1177/0022242919873106
# ID number 146: 10.1177/0038026119871401
# ID number 147: 10.4324/9781315114484
# ID number 148: 10.1109/ACIIW.2019.8925199
# ID number 149: 10.1177/2056305119861807
# ID number 150: 10.1109/CyberSA.2019.8899669
# ID number 151: 10.1146/annurev-publhealth-040119-094017
# ID number 152: 10.1163/9781848881259_006
# ID number 153: 10.1093/oso/9780190697846.001.0001
# ID number 154: 10.4324/9780429316159
# ID number 155: 10.1007/978-3-030-35166-3_41
# ID number 156: 10.5210/fm.v24i10.9593
# ID number 157: 10.1017/9781108394673
# ID number 158: 10.3233/JIFS-179023
# ID number 159: 10.5210/fm.v23i8.9136
# ID number 160: 10.1080/13562517.2018.1467162
# ID number 161: 10.1145/3232676
# ID number 162: 10.1007/978-3-319-69566-2
# ID number 163: 10.3390/socsci7030042
# ID number 164: 10.1007/978-3-319-73090-5
# ID number 165: 10.4324/9780429495557
# ID number 166: 10.4324/9781351103367
# ID number 167: 10.1007/978-3-319-89686-1
# ID number 168: 10.4000/books.aaccademia.4734
# ID number 169: 10.4000/books.aaccademia.4680
# ID number 170: 10.4000/books.aaccademia.4497
# ID number 171: 10.1515/zcph-2017-0006
# ID number 172: 10.1057/978-1-137-59174-6
# ID number 173: 10.1057/978-1-137-52702-8
# ID number 174: 10.4324/9781315166025
# ID number 175: 10.4324/9781315256498
# ID number 176: 10.1002/ab.21668
# ID number 177: 10.15446/revfacmed.v65n4.61615
# ID number 178: 10.1177/0361684315599346
# ID number 179: 10.1017/CBO9781316479766
# ID number 180: 10.1057/978-1-137-52527-7
# ID number 181: 10.4324/9781315794938
# ID number 182: 10.1057/9781137496980
# ID number 183: 10.1007/s11199-015-0558-x
# ID number 184: 10.4324/9781315696843
# ID number 185: 10.4324/9781315719634
# ID number 186: 10.1093/acprof:oso/9780195342703.001.0001
# ID number 187: 10.1016/j.poetic.2013.12.001
# ID number 188: 10.4324/9781315812335-11
# ID number 189: 10.4324/9781315778266
# ID number 190: 10.1017/9781315774305
# ID number 191: 10.4324/9781315797236
# ID number 192: 10.1093/acprof:oso/9780199892631.001.0001
# ID number 193: 10.4324/9780203143308-13
# ID number 194: 10.4324/9780203094020-9
# ID number 195: 10.4324/9780203143308
# ID number 196: 10.1037/a0028437
# ID number 197: 10.1075/z.177
# ID number 198: 10.1093/acprof:oso/9780199796373.001.0001
# ID number 199: 10.4324/9781843146063

# %%
df2 = pd.DataFrame(json_data3)
df2['index'] = df2.index
df2
# Out:
#                                       paperId  \
# 0    b3f6c70f4dcebc26a5d27fcd15efebdf3ba9de0d
# 1    52e723ec3c2200fa51004f585750e6a3f3841c79
# 2    e7c33ed5676b0a129ca4155641bb13aadf6feb90
# 3    b23c72917922454a27b67902ecec4c3191021073
# 4    72f1dcdfd73cfb56e62ca6b4396b49d344de94cf
# ..                                        ...
# 183  b2429f80820c7b06bee837568e5522e125023763
# 184  99ba6f0f45ca89f1edf7d1783512769f5d9ad26a
# 185  12c4a1ae5abe1b90f7d01e88c7dd33338a21d76b
# 186  3070324ec5b75e3bb0b475792628f756fe562c2c
# 187  2db58f5bd788043a47496f6659143cd9790f0001
#
#                                       publicationVenue  \
# 0    {'id': '987139ae-a65d-49bb-aaf6-fb764dc40b19',...
# 1    {'id': 'ec253390-208b-4979-9d5f-c9f654ad6181',...
# 2                                                 None
# 3    {'id': '68fd8242-3be0-4b1e-8b5d-ad0a8a02db12',...
# 4    {'id': '12fff95b-d469-49a0-84a5-4fd4696c3f28',...
# ..                                                 ...
# 183                                               None
# 184                                               None
# 185                                               None
# 186                                               None
# 187                                               None
#
#                                                  title  \
# 0    Detecting offensive speech in conversational c...
# 1    Online offensive behaviour in socialmedia: Det...
# 2    VAD-assisted multitask transformer framework f...
# 3    Towards multidomain and multilingual abusive l...
# 4    Multitasking of sentiment detection and emotio...
# ..                                                 ...
# 183  Violence and war in culture and the media : fi...
# 184  Associations Among Men's Sexist Attitudes, Obj...
# 185  An Interdisciplinary Bibliography on Language,...
# 186  State of Peril: Race and Rape in South African...
# 187     Women, Madness and the Law : A Feminist Reader
#
#                                               abstract  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 183  1. Introduction: Violence and War in Culture a...
# 184  The present study tested the hypothesis, deriv...
# 185  This comprehensive, state-of-the-art bibliogra...
# 186  Preface Introduction 1. Danger and Desire: Rap...
# 187  Only for you today! Discover your favourite wo...
#
#                                        venue    year  referenceCount  \
# 0           Expert systems with applications  2022.0              51
# 1                    Entertainment Computing  2023.0             113
# 2    Information Processing &amp; Management  2023.0              42
# 3          Personal and Ubiquitous Computing  2021.0             161
# 4                    Knowledge-Based Systems  2022.0              26
# ..                                       ...     ...             ...
# 183                                           2012.0               0
# 184                                           2013.0              82
# 185                                           2012.0               0
# 186                                           2012.0               0
# 187                                           2012.0               0
#
#      influentialCitationCount       fieldsOfStudy  \
# 0                           0                None
# 1                           0                None
# 2                           0                None
# 3                           0  [Computer Science]
# 4                           0  [Computer Science]
# ..                        ...                 ...
# 183                         0         [Sociology]
# 184                         5        [Psychology]
# 185                         0  [Computer Science]
# 186                         2           [History]
# 187                         0         [Sociology]
#
#                                                   tldr  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    {'model': 'tldr@v2.0.0', 'text': 'The current ...
# 4                                                 None
# ..                                                 ...
# 183                                               None
# 184                                               None
# 185  {'model': 'tldr@v2.0.0', 'text': 'This compreh...
# 186                                               None
# 187                                               None
#
#                                                authors  index
# 0    [{'authorId': '2085214622', 'name': 'Hiren Mad...      0
# 1    [{'authorId': '2198249048', 'name': 'Sneha Chi...      1
# 2    [{'authorId': '1409869614', 'name': 'Soumitra ...      2
# 3    [{'authorId': '9278845', 'name': 'Endang Wahyu...      3
# 4    [{'authorId': '1409869614', 'name': 'Soumitra ...      4
# ..                                                 ...    ...
# 183  [{'authorId': '66825750', 'name': 'Athina Kara...    183
# 184  [{'authorId': '3298993', 'name': 'V. Swami'}, ...    184
# 185  [{'authorId': '69405544', 'name': 'Heiko Motsc...    185
# 186   [{'authorId': '104954883', 'name': 'L. Graham'}]    186
# 187  [{'authorId': '143965359', 'name': 'Wendy Chan...    187
#
# [188 rows x 12 columns]

# %%
df2.columns
# Out:
# Index(['paperId', 'publicationVenue', 'title', 'abstract', 'venue', 'year',
#        'referenceCount', 'influentialCitationCount', 'fieldsOfStudy', 'tldr',
#        'authors', 'index'],
#       dtype='object')

# %% [markdown]
# #### Details about a paper's authors based on Paper ID

# %%
fields = 'affiliations,paperCount,citationCount,hIndex'

# %%
json_data4 = []
i = 0

for id in doi_ids: # As long as the url exists
    print(f'ID number {i}: {id}')
    i += 1

    # Make the request to get the paper ID which is needed for the next step
    responses = requests.get(f'https://api.semanticscholar.org/graph/v1/paper/{id}', headers=headers, stream = True)
    json = responses.json()
    # Check if 'paperId' is there in the json file
    if 'paperId' in json:
        paper_id = json['paperId']

        # make the second request to get the details of the authors 
        response = requests.get(f'https://api.semanticscholar.org/graph/v1/paper/{paper_id}/authors?fields={fields}', headers=headers, stream = True)
        json = response.json()
        json_data4.append([id, json]) # Adding the doi in this one to help merge with dataframe 'df'

    else: # if the request does not fetch anything
        continue
# Out:
# ID number 0: 10.1016/j.eswa.2022.119342
# ID number 1: 10.1016/j.entcom.2022.100544
# ID number 2: 10.1016/j.ipm.2022.103234
# ID number 3: 10.1007/s00779-021-01609-1
# ID number 4: 10.1016/j.knosys.2022.110182
# ID number 5: 10.1016/j.ipm.2022.103118
# ID number 6: 10.32604/cmc.2023.032993
# ID number 7: 10.1080/00224499.2022.2103071
# ID number 8: 10.1177/09579265221099380
# ID number 9: 10.1177/08862605221084747
# ID number 10: 10.1016/j.knosys.2022.109965
# ID number 11: 10.1007/s13278-022-00993-7
# ID number 12: 10.1007/s13278-022-00940-6
# ID number 13: 10.1145/3555618
# ID number 14: 10.1016/j.jjimei.2022.100119
# ID number 15: 10.1145/3549498
# ID number 16: 10.1371/journal.pone.0274317
# ID number 17: 10.1016/j.dib.2022.108526
# ID number 18: 10.1016/j.engappai.2022.105283
# ID number 19: 10.1145/3551349.3559571
# ID number 20: 10.1145/3551349.3559515
# ID number 21: 10.23940/ijpe.22.09.p8.668678
# ID number 22: 10.26441/RC21.2-2022-A2
# ID number 23: 10.26342/2022-69-19
# ID number 24: 10.26342/2022-69-20
# ID number 25: 10.1016/j.jag.2022.102967
# ID number 26: 10.1016/j.array.2022.100217
# ID number 27: 10.1016/j.eswa.2022.117032
# ID number 28: 10.1007/s10612-021-09604-x
# ID number 29: 10.3366/cor.2022.0255
# ID number 30: 10.1177/21533687221101793
# ID number 31: 10.1007/s11263-022-01625-5
# ID number 32: 10.1016/j.osnem.2022.100210
# ID number 33: 10.5755/j01.itc.51.2.29988
# ID number 34: 10.1145/3530901
# ID number 35: 10.3390/info13060273
# ID number 36: 10.1145/3487061
# ID number 37: 10.1016/j.comcom.2022.03.021
# ID number 38: 10.1016/j.future.2021.12.011
# ID number 39: 10.1177/0886260520967143
# ID number 40: 10.1007/s40747-021-00625-1
# ID number 41: 10.1007/s10586-021-03483-1
# ID number 42: 10.3390/math10060945
# ID number 43: 10.1145/3488560.3501392
# ID number 44: 10.6018/reifop.533411
# ID number 45: 10.1109/ICOIACT55506.2022.9972171
# ID number 46: 10.47750/pnr.2022.13.S03.072
# ID number 47: 10.1007/s10508-022-02502-5
# ID number 48: 10.4324/9781003081388
# ID number 49: 10.4324/9781003195542
# ID number 50: 10.1108/GM-01-2021-0026
# ID number 51: 10.1007/978-3-031-16270-1_21
# ID number 52: 10.21512/commit.v16i2.8343
# ID number 53: 10.1007/978-3-031-08421-8_19
# ID number 54: 10.1007/s40747-022-00693-x
# ID number 55: 10.4324/9780429291975
# ID number 56: 10.1037/sgd0000574
# ID number 57: 10.1155/2022/7937667
# ID number 58: 10.7717/PEERJ-CS.906
# ID number 59: 10.1080/14680777.2022.2047089
# ID number 60: 10.1007/s10579-022-09582-8
# ID number 61: 10.1145/3457610
# ID number 62: 10.1109/ACCESS.2022.3147588
# ID number 63: 10.1109/ACCESS.2022.3140342
# ID number 64: 10.1016/j.osnem.2021.100182
# ID number 65: 10.1080/17539153.2021.2005099
# ID number 66: 10.1007/s10508-021-02100-x
# ID number 67: 10.1007/s12559-021-09862-5
# ID number 68: 10.1080/09589236.2021.1881461
# ID number 69: 10.1007/s12559-021-09845-6
# ID number 70: 10.1016/j.eswa.2021.115632
# ID number 71: 10.1145/3503162.3503168
# ID number 72: 10.1007/s41019-021-00168-y
# ID number 73: 10.1111/sjop.12763
# ID number 74: 10.1007/s10579-021-09530-y
# ID number 75: 10.1371/journal.pone.0243300
# ID number 76: 10.1145/3501774.3501797
# ID number 77: 10.1145/3487351.3488342
# ID number 78: 10.3390/app112210801
# ID number 79: 10.1145/3475716.3484189
# ID number 80: 10.1332/239868021X16286662118554
# ID number 81: 10.3145/epi.2021.sep.02
# ID number 82: 10.1371/journal.pone.0257903
# ID number 83: 10.26342/2021-67-17
# ID number 84: 10.1016/j.ipm.2021.102643
# ID number 85: 10.1515/jso-2021-0033
# ID number 86: 10.1016/j.eswa.2021.114802
# ID number 87: 10.1613/JAIR.1.12590
# ID number 88: 10.1145/3457189
# ID number 89: 10.1145/3447535.3462502
# ID number 90: 10.1016/j.ipm.2021.102524
# ID number 91: 10.3390/math9080807
# ID number 92: 10.1177/1464700120988643
# ID number 93: 10.1016/j.eswa.2020.114120
# ID number 94: 10.26342/2021-66-5
# ID number 95: 10.1177/0956797620968529
# ID number 96: 10.1038/s41443-020-0302-0
# ID number 97: 10.1080/08164649.2022.2062669
# ID number 98: 10.1109/CogMI52975.2021.00014
# ID number 99: 10.1109/SNAMS53716.2021.9732077
# ID number 100: 10.1007/s40747-021-00561-0
# ID number 101: 10.1109/ICMLA52953.2021.00253
# ID number 102: 10.1109/BigData52589.2021.9671478
# ID number 103: 10.1109/BigData52589.2021.9671823
# ID number 104: 10.1109/BigData52589.2021.9672065
# ID number 105: 10.1109/SMC52423.2021.9659158
# ID number 106: 10.7203/QF.0.21982
# ID number 107: 10.1525/luminos.110
# ID number 108: 10.1007/978-3-030-81462-5_46
# ID number 109: 10.1109/ACCESS.2021.3103459
# ID number 110: 10.1109/ACCESS.2021.3103697
# ID number 111: 10.1177/20563051211036939
# ID number 112: 10.7717/peerj-cs.559
# ID number 113: 10.7717/PEERJ-CS.598
# ID number 114: 10.1080/21670811.2021.1882868
# ID number 115: 10.1108/QRJ-09-2020-0108
# ID number 116: 10.1007/978-981-16-0401-0_26
# ID number 117: 10.1080/14442213.2021.1882548
# ID number 118: 10.3390/electronics10010005
# ID number 119: 10.1080/09589236.2020.1834368
# ID number 120: 10.1016/j.future.2020.08.032
# ID number 121: 10.4018/978-1-7998-3763-3
# ID number 122: 10.1109/CSCI51800.2020.00051
# ID number 123: 10.1016/j.ipm.2020.102360
# ID number 124: 10.1145/3340531.3412764
# ID number 125: 10.1080/14680777.2019.1643387
# ID number 126: 10.26342/2020-65-13
# ID number 127: 10.1086/709362
# ID number 128: 10.3390/PUBLICATIONS8030041
# ID number 129: 10.1177/0038026120934690
# ID number 130: 10.1145/3369869
# ID number 131: 10.1145/3313831.3376645
# ID number 132: 10.1080/1369118X.2020.1713843
# ID number 133: 10.14361/9783839451540
# ID number 134: 10.1016/j.bodyim.2020.01.006
# ID number 135: 10.1016/j.cose.2019.101710
# ID number 136: 10.1080/13572334.2020.1730502
# ID number 137: 10.1109/ACCESS.2020.3042604
# ID number 138: 10.4324/9781003037965
# ID number 139: 10.1093/oso/9780190084448.001.0001
# ID number 140: 10.1007/978-3-030-62008-0_37
# ID number 141: 10.1007/978-3-030-62015-8_4
# ID number 142: 10.1007/978-3-030-62015-8_3
# ID number 143: 10.5771/1615-634X-2020-3-211
# ID number 144: 10.1891/VV-D-18-00159
# ID number 145: 10.1177/0022242919873106
# ID number 146: 10.1177/0038026119871401
# ID number 147: 10.4324/9781315114484
# ID number 148: 10.1109/ACIIW.2019.8925199
# ID number 149: 10.1177/2056305119861807
# ID number 150: 10.1109/CyberSA.2019.8899669
# ID number 151: 10.1146/annurev-publhealth-040119-094017
# ID number 152: 10.1163/9781848881259_006
# ID number 153: 10.1093/oso/9780190697846.001.0001
# ID number 154: 10.4324/9780429316159
# ID number 155: 10.1007/978-3-030-35166-3_41
# ID number 156: 10.5210/fm.v24i10.9593
# ID number 157: 10.1017/9781108394673
# ID number 158: 10.3233/JIFS-179023
# ID number 159: 10.5210/fm.v23i8.9136
# ID number 160: 10.1080/13562517.2018.1467162
# ID number 161: 10.1145/3232676
# ID number 162: 10.1007/978-3-319-69566-2
# ID number 163: 10.3390/socsci7030042
# ID number 164: 10.1007/978-3-319-73090-5
# ID number 165: 10.4324/9780429495557
# ID number 166: 10.4324/9781351103367
# ID number 167: 10.1007/978-3-319-89686-1
# ID number 168: 10.4000/books.aaccademia.4734
# ID number 169: 10.4000/books.aaccademia.4680
# ID number 170: 10.4000/books.aaccademia.4497
# ID number 171: 10.1515/zcph-2017-0006
# ID number 172: 10.1057/978-1-137-59174-6
# ID number 173: 10.1057/978-1-137-52702-8
# ID number 174: 10.4324/9781315166025
# ID number 175: 10.4324/9781315256498
# ID number 176: 10.1002/ab.21668
# ID number 177: 10.15446/revfacmed.v65n4.61615
# ID number 178: 10.1177/0361684315599346
# ID number 179: 10.1017/CBO9781316479766
# ID number 180: 10.1057/978-1-137-52527-7
# ID number 181: 10.4324/9781315794938
# ID number 182: 10.1057/9781137496980
# ID number 183: 10.1007/s11199-015-0558-x
# ID number 184: 10.4324/9781315696843
# ID number 185: 10.4324/9781315719634
# ID number 186: 10.1093/acprof:oso/9780195342703.001.0001
# ID number 187: 10.1016/j.poetic.2013.12.001
# ID number 188: 10.4324/9781315812335-11
# ID number 189: 10.4324/9781315778266
# ID number 190: 10.1017/9781315774305
# ID number 191: 10.4324/9781315797236
# ID number 192: 10.1093/acprof:oso/9780199892631.001.0001
# ID number 193: 10.4324/9780203143308-13
# ID number 194: 10.4324/9780203094020-9
# ID number 195: 10.4324/9780203143308
# ID number 196: 10.1037/a0028437
# ID number 197: 10.1075/z.177
# ID number 198: 10.1093/acprof:oso/9780199796373.001.0001
# ID number 199: 10.4324/9781843146063

# %%
df3 = pd.DataFrame(json_data4).rename(columns={0: 'prism:doi', 1: 'author_data'})
df3['author_data'] = pd.json_normalize(df3['author_data']).data
df3['index'] = df3.index
df3
# Out:
#                                      prism:doi  \
# 0                   10.1016/j.eswa.2022.119342
# 1                 10.1016/j.entcom.2022.100544
# 2                    10.1016/j.ipm.2022.103234
# 3                   10.1007/s00779-021-01609-1
# 4                 10.1016/j.knosys.2022.110182
# ..                                         ...
# 183                      10.4324/9780203143308
# 184                           10.1037/a0028437
# 185                              10.1075/z.177
# 186  10.1093/acprof:oso/9780199796373.001.0001
# 187                      10.4324/9781843146063
#
#                                            author_data  index
# 0    [{'authorId': '2085214622', 'affiliations': []...      0
# 1    [{'authorId': '2198249048', 'affiliations': []...      1
# 2    [{'authorId': '1409869614', 'affiliations': ['...      2
# 3    [{'authorId': '9278845', 'affiliations': [], '...      3
# 4    [{'authorId': '1409869614', 'affiliations': ['...      4
# ..                                                 ...    ...
# 183  [{'authorId': '66825750', 'affiliations': [], ...    183
# 184  [{'authorId': '3298993', 'affiliations': [], '...    184
# 185  [{'authorId': '69405544', 'affiliations': [], ...    185
# 186  [{'authorId': '104954883', 'affiliations': [],...    186
# 187  [{'authorId': '143965359', 'affiliations': [],...    187
#
# [188 rows x 3 columns]

# %% [markdown]
# Merge the last two dataframes and remove the drop the columns we do not need.

# %%
df_2_3 = pd.merge(df2, df3, on="index", how="left").drop(columns=['paperId', 'index']) 
df_2_3
# Out:
#                                       publicationVenue  \
# 0    {'id': '987139ae-a65d-49bb-aaf6-fb764dc40b19',...
# 1    {'id': 'ec253390-208b-4979-9d5f-c9f654ad6181',...
# 2                                                 None
# 3    {'id': '68fd8242-3be0-4b1e-8b5d-ad0a8a02db12',...
# 4    {'id': '12fff95b-d469-49a0-84a5-4fd4696c3f28',...
# ..                                                 ...
# 183                                               None
# 184                                               None
# 185                                               None
# 186                                               None
# 187                                               None
#
#                                                  title  \
# 0    Detecting offensive speech in conversational c...
# 1    Online offensive behaviour in socialmedia: Det...
# 2    VAD-assisted multitask transformer framework f...
# 3    Towards multidomain and multilingual abusive l...
# 4    Multitasking of sentiment detection and emotio...
# ..                                                 ...
# 183  Violence and war in culture and the media : fi...
# 184  Associations Among Men's Sexist Attitudes, Obj...
# 185  An Interdisciplinary Bibliography on Language,...
# 186  State of Peril: Race and Rape in South African...
# 187     Women, Madness and the Law : A Feminist Reader
#
#                                               abstract  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 183  1. Introduction: Violence and War in Culture a...
# 184  The present study tested the hypothesis, deriv...
# 185  This comprehensive, state-of-the-art bibliogra...
# 186  Preface Introduction 1. Danger and Desire: Rap...
# 187  Only for you today! Discover your favourite wo...
#
#                                        venue    year  referenceCount  \
# 0           Expert systems with applications  2022.0              51
# 1                    Entertainment Computing  2023.0             113
# 2    Information Processing &amp; Management  2023.0              42
# 3          Personal and Ubiquitous Computing  2021.0             161
# 4                    Knowledge-Based Systems  2022.0              26
# ..                                       ...     ...             ...
# 183                                           2012.0               0
# 184                                           2013.0              82
# 185                                           2012.0               0
# 186                                           2012.0               0
# 187                                           2012.0               0
#
#      influentialCitationCount       fieldsOfStudy  \
# 0                           0                None
# 1                           0                None
# 2                           0                None
# 3                           0  [Computer Science]
# 4                           0  [Computer Science]
# ..                        ...                 ...
# 183                         0         [Sociology]
# 184                         5        [Psychology]
# 185                         0  [Computer Science]
# 186                         2           [History]
# 187                         0         [Sociology]
#
#                                                   tldr  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    {'model': 'tldr@v2.0.0', 'text': 'The current ...
# 4                                                 None
# ..                                                 ...
# 183                                               None
# 184                                               None
# 185  {'model': 'tldr@v2.0.0', 'text': 'This compreh...
# 186                                               None
# 187                                               None
#
#                                                authors  \
# 0    [{'authorId': '2085214622', 'name': 'Hiren Mad...
# 1    [{'authorId': '2198249048', 'name': 'Sneha Chi...
# 2    [{'authorId': '1409869614', 'name': 'Soumitra ...
# 3    [{'authorId': '9278845', 'name': 'Endang Wahyu...
# 4    [{'authorId': '1409869614', 'name': 'Soumitra ...
# ..                                                 ...
# 183  [{'authorId': '66825750', 'name': 'Athina Kara...
# 184  [{'authorId': '3298993', 'name': 'V. Swami'}, ...
# 185  [{'authorId': '69405544', 'name': 'Heiko Motsc...
# 186   [{'authorId': '104954883', 'name': 'L. Graham'}]
# 187  [{'authorId': '143965359', 'name': 'Wendy Chan...
#
#                                      prism:doi  \
# 0                   10.1016/j.eswa.2022.119342
# 1                 10.1016/j.entcom.2022.100544
# 2                    10.1016/j.ipm.2022.103234
# 3                   10.1007/s00779-021-01609-1
# 4                 10.1016/j.knosys.2022.110182
# ..                                         ...
# 183                      10.4324/9780203143308
# 184                           10.1037/a0028437
# 185                              10.1075/z.177
# 186  10.1093/acprof:oso/9780199796373.001.0001
# 187                      10.4324/9781843146063
#
#                                            author_data
# 0    [{'authorId': '2085214622', 'affiliations': []...
# 1    [{'authorId': '2198249048', 'affiliations': []...
# 2    [{'authorId': '1409869614', 'affiliations': ['...
# 3    [{'authorId': '9278845', 'affiliations': [], '...
# 4    [{'authorId': '1409869614', 'affiliations': ['...
# ..                                                 ...
# 183  [{'authorId': '66825750', 'affiliations': [], ...
# 184  [{'authorId': '3298993', 'affiliations': [], '...
# 185  [{'authorId': '69405544', 'affiliations': [], ...
# 186  [{'authorId': '104954883', 'affiliations': [],...
# 187  [{'authorId': '143965359', 'affiliations': [],...
#
# [188 rows x 12 columns]

# %% [markdown]
# Now check with the df dataframe to remove unneccessary columns.

# %%
# choose the columns we can remove
df.srctype.unique() # Not important
df.eid.unique() # (Electronic ID) -- not important
df['dc:description'].unique() # (Abstracts) -- important
df['prism:url'].unique() # (Content Abstract Retrieval API URI) -- not important
df['prism:coverDate'].unique() # (Publication Date) -- important
df['prism:aggregationType'].unique() # (Source Type) -- important
df['subtypeDescription'].unique() # (Document Type description) -- important
df['link'] # not important
df['prism:publicationName'].unique() # (Source Title) -- important
df['source-id'].unique() # keep for later use
df['citedby-count'].unique() # (Cited-by Count) -- important
df['prism:volume'].unique() # (Volume) -- important
df['subtype'].unique() # (Document Type code) -- not important
df['dc:title'].unique() # (Article Title) -- important
df['openaccess'].unique() # (Open Access status) -- keep for later use
df['openaccessFlag'].unique() # keep for later use
df['prism:doi'] # (Document Object Identifier) -- keep to merge the datasets
df['prism:issn'].unique() # (Source identifier) -- not important
df['dc:identifier'] # (Scopus ID) -- not important
df['dc:publisher'] # keep for later use
df['prism:issueIdentifier'] # not important
df['article-number'] # not important
df['pubmed-id'] # not important
df['prism:pageRange'] # not important
df['prism:endingPage'] # not important
df['prism:startingPage'] # not important
df['pii'] # not important
df['prism:isbn'] # (Source identifier) -- not important
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#                              ...
# 316                                       9781438444079
# 317       [{'$': '029928994X'}, {'$': '9780299289942'}]
# 318    [{'$': '9789027273154'}, {'$': '9789027212009'}]
# 319    [{'$': '9780199933327'}, {'$': '9780199796373'}]
# 320                                       9781843146063
# Name: prism:isbn, Length: 321, dtype: object

# %%
df = df.drop(columns=[
    'srctype', 'eid', 'prism:url',
    'link', 'subtype', 'prism:issn', 'dc:identifier',
    'prism:issueIdentifier', 'article-number', 'pubmed-id', 'prism:pageRange',
    'prism:endingPage', 'prism:startingPage', 'pii','prism:isbn'
    ])

# %%
df.columns
# Out:
# Index(['dc:description', 'prism:coverDate', 'prism:aggregationType',
#        'subtypeDescription', 'dc:creator', 'prism:publicationName',
#        'source-id', 'citedby-count', 'prism:volume', 'dc:title', 'openaccess',
#        'openaccessFlag', 'prism:doi', 'dc:publisher', 'index'],
#       dtype='object')

# %%
# to check later if the dataframes are properly merged
df[df['prism:doi'].isna()].index
# Out:
# Int64Index([ 46,  47,  48,  49,  50,  51,  52,  55,  57,  60,
#             ...
#             281, 283, 284, 285, 286, 287, 301, 310, 316, 317],
#            dtype='int64', length=121)

# %%
df = pd.merge(df, df_2_3, on='prism:doi', how='left')
df
# Out:
#                                         dc:description prism:coverDate  \
# 0    © 2022 Elsevier LtdThe spread of Hate Speech o...      2023-04-01
# 1    © 2022 Elsevier B.V.The enormous growth of soc...      2023-03-01
# 2    © 2022 Elsevier LtdDetecting suicidal tendenci...      2023-03-01
# 3    © 2021, The Author(s).Abusive language is an i...      2023-02-01
# 4    © 2022 Elsevier B.V.As the number of non-nativ...      2023-01-25
# ..                                                 ...             ...
# 316  Argues that South Africa's apartheid system of...      2012-12-01
# 317  In Russia during the second half of the eighte...      2012-12-01
# 318  © 2012 - John Benjamins B.V.This comprehensive...      2012-09-11
# 319  © 2012 by Oxford University Press, Inc. All ri...      2012-05-24
# 320  © 2005 by Lawrence Erlbaum Associates, Inc.Thi...      2012-01-01
#
#     prism:aggregationType subtypeDescription  \
# 0                 Journal            Article
# 1                 Journal             Review
# 2                 Journal            Article
# 3                 Journal            Article
# 4                 Journal            Article
# ..                    ...                ...
# 316                  Book               Book
# 317                  Book               Book
# 318                  Book               Book
# 319                  Book               Book
# 320                  Book               Book
#
#                                             dc:creator  \
# 0    {'author': [{'ce:given-name': 'Hiren', 'prefer...
# 1    {'author': [{'ce:given-name': 'Sneha', 'prefer...
# 2    {'author': [{'ce:given-name': 'Soumitra', 'pre...
# 3    {'author': [{'ce:given-name': 'Endang Wahyu', ...
# 4    {'author': [{'ce:given-name': 'Soumitra', 'pre...
# ..                                                 ...
# 316  {'author': [{'ce:given-name': 'Amanda Lock', '...
# 317  {'author': [{'ce:given-name': 'Anna', 'preferr...
# 318  {'author': [{'ce:given-name': 'Heiko', 'prefer...
# 319  {'author': [{'ce:given-name': 'Lucy Valerie', ...
# 320  {'author': [{'ce:given-name': 'Wendy', 'prefer...
#
#                                  prism:publicationName    source-id  \
# 0                     Expert Systems with Applications        24201
# 1                              Entertainment Computing  19400158708
# 2                Information Processing and Management        12689
# 3                    Personal and Ubiquitous Computing        22315
# 4                              Knowledge-Based Systems        24772
# ..                                                 ...          ...
# 316  Sex in Transition: Remaking Gender and Race in...  21100315756
# 317  From the Womb to the Body Politic: Raising the...  21100314688
# 318  An Interdisciplinary Bibliography on Language,...  21100420846
# 319  State of Peril: Race and Rape in South African...  21100373304
# 320      Women, Madness and the Law: A Feminist Reader  21100382236
#
#     citedby-count prism:volume  \
# 0               1          215
# 1               0           45
# 2               0           60
# 3               3           27
# 4               0          260
# ..            ...          ...
# 316            35          NaN
# 317             1          NaN
# 318             8          NaN
# 319            46          NaN
# 320             0          NaN
#
#                                               dc:title  ...  \
# 0    Detecting offensive speech in conversational c...  ...
# 1    Online offensive behaviour in socialmedia: Det...  ...
# 2    VAD-assisted multitask transformer framework f...  ...
# 3    Towards multidomain and multilingual abusive l...  ...
# 4    Multitasking of sentiment detection and emotio...  ...
# ..                                                 ...  ...
# 316  Sex in transition: Remaking gender and race in...  ...
# 317  From the womb to the body politic: Raising the...  ...
# 318  An interdisciplinary bibliography on language,...  ...
# 319  State of Peril: Race and Rape in South African...  ...
# 320      Women, madness and the law: A feminist reader  ...
#
#                                                  title  \
# 0    Detecting offensive speech in conversational c...
# 1    Online offensive behaviour in socialmedia: Det...
# 2    VAD-assisted multitask transformer framework f...
# 3    Towards multidomain and multilingual abusive l...
# 4    Multitasking of sentiment detection and emotio...
# ..                                                 ...
# 316                                                NaN
# 317                                                NaN
# 318  An Interdisciplinary Bibliography on Language,...
# 319  State of Peril: Race and Rape in South African...
# 320     Women, Madness and the Law : A Feminist Reader
#
#                                               abstract  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 316                                                NaN
# 317                                                NaN
# 318  This comprehensive, state-of-the-art bibliogra...
# 319  Preface Introduction 1. Danger and Desire: Rap...
# 320  Only for you today! Discover your favourite wo...
#
#                                        venue    year  referenceCount  \
# 0           Expert systems with applications  2022.0            51.0
# 1                    Entertainment Computing  2023.0           113.0
# 2    Information Processing &amp; Management  2023.0            42.0
# 3          Personal and Ubiquitous Computing  2021.0           161.0
# 4                    Knowledge-Based Systems  2022.0            26.0
# ..                                       ...     ...             ...
# 316                                      NaN     NaN             NaN
# 317                                      NaN     NaN             NaN
# 318                                           2012.0             0.0
# 319                                           2012.0             0.0
# 320                                           2012.0             0.0
#
#     influentialCitationCount       fieldsOfStudy  \
# 0                        0.0                None
# 1                        0.0                None
# 2                        0.0                None
# 3                        0.0  [Computer Science]
# 4                        0.0  [Computer Science]
# ..                       ...                 ...
# 316                      NaN                 NaN
# 317                      NaN                 NaN
# 318                      0.0  [Computer Science]
# 319                      2.0           [History]
# 320                      0.0         [Sociology]
#
#                                                   tldr  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    {'model': 'tldr@v2.0.0', 'text': 'The current ...
# 4                                                 None
# ..                                                 ...
# 316                                                NaN
# 317                                                NaN
# 318  {'model': 'tldr@v2.0.0', 'text': 'This compreh...
# 319                                               None
# 320                                               None
#
#                                                authors  \
# 0    [{'authorId': '2085214622', 'name': 'Hiren Mad...
# 1    [{'authorId': '2198249048', 'name': 'Sneha Chi...
# 2    [{'authorId': '1409869614', 'name': 'Soumitra ...
# 3    [{'authorId': '9278845', 'name': 'Endang Wahyu...
# 4    [{'authorId': '1409869614', 'name': 'Soumitra ...
# ..                                                 ...
# 316                                                NaN
# 317                                                NaN
# 318  [{'authorId': '69405544', 'name': 'Heiko Motsc...
# 319   [{'authorId': '104954883', 'name': 'L. Graham'}]
# 320  [{'authorId': '143965359', 'name': 'Wendy Chan...
#
#                                            author_data
# 0    [{'authorId': '2085214622', 'affiliations': []...
# 1    [{'authorId': '2198249048', 'affiliations': []...
# 2    [{'authorId': '1409869614', 'affiliations': ['...
# 3    [{'authorId': '9278845', 'affiliations': [], '...
# 4    [{'authorId': '1409869614', 'affiliations': ['...
# ..                                                 ...
# 316                                                NaN
# 317                                                NaN
# 318  [{'authorId': '69405544', 'affiliations': [], ...
# 319  [{'authorId': '104954883', 'affiliations': [],...
# 320  [{'authorId': '143965359', 'affiliations': [],...
#
# [321 rows x 26 columns]

# %% [markdown]
# Check with some of the indices as specified before. Let's say 137 and 255.

# %%
df.iloc[137]
# Out:
# dc:description              © 2021 Sociedad Española para el Procesamiento...
# prism:coverDate                                                    2021-09-01
# prism:aggregationType                                                 Journal
# subtypeDescription                                                     Review
# dc:creator                  {'author': [{'ce:given-name': 'Francisco', 'pr...
# prism:publicationName                      Procesamiento del Lenguaje Natural
# source-id                                                         21100195304
# citedby-count                                                              47
# prism:volume                                                               67
# dc:title                    Overview of EXIST 2021: sEXism Identification ...
# openaccess                                                               None
# openaccessFlag                                                           None
# prism:doi                                                 10.26342/2021-67-17
# dc:publisher                Sociedad Espanola para el Procesamiento del Le...
# index                                                                     137
# publicationVenue                                                         None
# title                       Overview of EXIST 2021: sEXism Identification ...
# abstract                    The paper describes the organization, goals, a...
# venue                                               Proces. del Leng. Natural
# year                                                                   2021.0
# referenceCount                                                           30.0
# influentialCitationCount                                                  9.0
# fieldsOfStudy                                              [Computer Science]
# tldr                        {'model': 'tldr@v2.0.0', 'text': 'The organiza...
# authors                     [{'authorId': '1403518310', 'name': 'F. Rodríg...
# author_data                 [{'authorId': '1403518310', 'affiliations': []...
# Name: 137, dtype: object

# %%
df.iloc[255]
# Out:
# dc:description              Copyright © 2020 by Annual Reviews.Racism. Sex...
# prism:coverDate                                                    2019-04-01
# prism:aggregationType                                             Book Series
# subtypeDescription                                                     Review
# dc:creator                  {'author': [{'ce:given-name': 'Nancy', 'prefer...
# prism:publicationName                          Annual Review of Public Health
# source-id                                                               19584
# citedby-count                                                             124
# prism:volume                                                               41
# dc:title                    Measures of racism, sexism, heterosexism, and ...
# openaccess                                                                  1
# openaccessFlag                                                           true
# prism:doi                            10.1146/annurev-publhealth-040119-094017
# dc:publisher                Annual Reviews Inc.4139 El Camino Way, P.O. Bo...
# index                                                                     255
# publicationVenue            {'id': '641e5cdb-8620-434d-9779-cb9bcf16cd93',...
# title                       Measures of Racism, Sexism, Heterosexism, and ...
# abstract                    Racism. Sexism. Heterosexism. Gender binarism....
# venue                                          Annual Review of Public Health
# year                                                                   2019.0
# referenceCount                                                          202.0
# influentialCitationCount                                                  7.0
# fieldsOfStudy                                           [Medicine, Sociology]
# tldr                        {'model': 'tldr@v2.0.0', 'text': 'Guided by th...
# authors                     [{'authorId': '144810681', 'name': 'N. Krieger'}]
# author_data                 [{'authorId': '144810681', 'affiliations': [],...
# Name: 255, dtype: object

# %% [markdown]
# Now check with two other random indices not from the previous list.

# %%
df.iloc[111]
# Out:
# dc:description              © 2022 Abdullah Y. Muaad et al.Social media ne...
# prism:coverDate                                                    2022-01-01
# prism:aggregationType                                                 Journal
# subtypeDescription                                                    Article
# dc:creator                  {'author': [{'ce:given-name': 'Abdullah Y.', '...
# prism:publicationName             Computational Intelligence and Neuroscience
# source-id                                                          7000153240
# citedby-count                                                               6
# prism:volume                                                             2022
# dc:title                    Artificial Intelligence-Based Approach for Mis...
# openaccess                                                                  1
# openaccessFlag                                                           true
# prism:doi                                                10.1155/2022/7937667
# dc:publisher                                                  Hindawi Limited
# index                                                                     111
# publicationVenue            {'id': 'f32b7322-b69c-4e63-801d-8f50784ef778',...
# title                       Artificial Intelligence-Based Approach for Mis...
# abstract                    Social media networking is a prominent topic i...
# venue                             Computational Intelligence and Neuroscience
# year                                                                   2022.0
# referenceCount                                                           42.0
# influentialCitationCount                                                  0.0
# fieldsOfStudy                                                      [Medicine]
# tldr                        {'model': 'tldr@v2.0.0', 'text': 'The proposed...
# authors                     [{'authorId': '2123504137', 'name': 'A. Y. Mua...
# author_data                 [{'authorId': '2123504137', 'affiliations': []...
# Name: 111, dtype: object

# %%
df.iloc[500]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/aditidutta/Library/CloudStorage/OneDrive-UniversityofExeter/Miscellaneous/Research-Paper-Explorer/Elsevier API/api_data_collection.ipynb Cell 60 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/aditidutta/Library/CloudStorage/OneDrive-UniversityofExeter/Miscellaneous/Research-Paper-Explorer/Elsevier%20API/api_data_collection.ipynb#Y113sZmlsZQ%3D%3D?line=0'>1</a> df.iloc[500]
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/pandas/core/indexing.py:1520, in _iLocIndexer._getitem_axis(self, key, axis)
#    1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
# -> 1520 self._validate_integer(key, axis)
#    1522 return self.obj._ixs(key, axis=axis)
#
# File ~/yes/envs/mlp/lib/python3.8/site-packages/pandas/core/indexing.py:1452, in _iLocIndexer._validate_integer(self, key, axis)
#    1450 len_axis = len(self.obj._get_axis(axis))
#    1451 if key >= len_axis or key < -len_axis:
# -> 1452     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ### Authors

# %%
authors = pd.json_normalize(df['authors'])
authors
# Out:
#                                                    0    \
# 0    {'authorId': '2085214622', 'name': 'Hiren Madhu'}
# 1    {'authorId': '2198249048', 'name': 'Sneha Chin...
# 2    {'authorId': '1409869614', 'name': 'Soumitra G...
# 3    {'authorId': '9278845', 'name': 'Endang Wahyu ...
# 4    {'authorId': '1409869614', 'name': 'Soumitra G...
# ..                                                 ...
# 316                                               None
# 317                                               None
# 318  {'authorId': '69405544', 'name': 'Heiko Motsch...
# 319     {'authorId': '104954883', 'name': 'L. Graham'}
# 320    {'authorId': '143965359', 'name': 'Wendy Chan'}
#
#                                                    1    \
# 0    {'authorId': '2057059204', 'name': 'Shrey Sata...
# 1     {'authorId': '2198254237', 'name': 'Roopa M.S.'}
# 2        {'authorId': '1734904', 'name': 'Asif Ekbal'}
# 3    {'authorId': '3101511', 'name': 'Valerio Basile'}
# 4    {'authorId': '2194830832', 'name': 'Amit Priya...
# ..                                                 ...
# 316                                               None
# 317                                               None
# 318                                               None
# 319                                               None
# 320        {'authorId': '8394097', 'name': 'D. Chunn'}
#
#                                                    2    \
# 0    {'authorId': '33682998', 'name': 'Sandip J Mod...
# 1    {'authorId': '2198254207', 'name': 'Arunalatha...
# 2    {'authorId': '145532184', 'name': 'P. Bhattach...
# 3          {'authorId': '1787198', 'name': 'V. Patti'}
# 4        {'authorId': '1734904', 'name': 'Asif Ekbal'}
# ..                                                 ...
# 316                                               None
# 317                                               None
# 318                                               None
# 319                                               None
# 320     {'authorId': '48014805', 'name': 'R. Menzies'}
#
#                                                    3    \
# 0     {'authorId': '32416012', 'name': 'Thomas Mandl'}
# 1    {'authorId': '2093461647', 'name': 'Venugopal ...
# 2                                                 None
# 3                                                 None
# 4    {'authorId': '145532184', 'name': 'P. Bhattach...
# ..                                                 ...
# 316                                               None
# 317                                               None
# 318                                               None
# 319                                               None
# 320                                               None
#
#                                                    4     5     6     7    \
# 0    {'authorId': '1911868', 'name': 'Prasenjit Maj...  None  None  None
# 1                                                 None  None  None  None
# 2                                                 None  None  None  None
# 3                                                 None  None  None  None
# 4                                                 None  None  None  None
# ..                                                 ...   ...   ...   ...
# 316                                               None  None  None  None
# 317                                               None  None  None  None
# 318                                               None  None  None  None
# 319                                               None  None  None  None
# 320                                               None  None  None  None
#
#       8     9    ...   94    95    96    97    98    99    100   101   102  \
# 0    None  None  ...  None  None  None  None  None  None  None  None  None
# 1    None  None  ...  None  None  None  None  None  None  None  None  None
# 2    None  None  ...  None  None  None  None  None  None  None  None  None
# 3    None  None  ...  None  None  None  None  None  None  None  None  None
# 4    None  None  ...  None  None  None  None  None  None  None  None  None
# ..    ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 316  None  None  ...  None  None  None  None  None  None  None  None  None
# 317  None  None  ...  None  None  None  None  None  None  None  None  None
# 318  None  None  ...  None  None  None  None  None  None  None  None  None
# 319  None  None  ...  None  None  None  None  None  None  None  None  None
# 320  None  None  ...  None  None  None  None  None  None  None  None  None
#
#       103
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# ..    ...
# 316  None
# 317  None
# 318  None
# 319  None
# 320  None
#
# [321 rows x 104 columns]

# %%
authors[0].isna().sum() # Interesting that 23 manuscripts do not have any first author
# Out:
# 134

# %%
print("Number of null values in authors: \n First author: {first}\n Second author: {second} \n Third author: {third} \n Fourth author: {fourth}\n Fifth author: {fifth}\n Sixth author: {sixth}".format(first=authors[0].isna().sum(), second= authors[1].isna().sum(), third= authors[2].isna().sum(), fourth= authors[3].isna().sum(), fifth= authors[4].isna().sum(), sixth= authors[5].isna().sum()))
# Out:
# Number of null values in authors:
#  First author: 134
#  Second author: 168
#  Third author: 213
#  Fourth author: 254
#  Fifth author: 286
#  Sixth author: 301

# %% [markdown]
# ### Separate the authors' name and id from the dictionary

# %%
nested_authors1 = pd.json_normalize(authors[0]).rename(columns={'authorId':'author_1_id', 'name':'author_1_name'})
nested_authors1['index'] = nested_authors1.index
nested_authors1
# Out:
#     author_1_id           author_1_name  index
# 0    2085214622             Hiren Madhu      0
# 1    2198249048          Sneha Chinivar      1
# 2    1409869614          Soumitra Ghosh      2
# 3       9278845  Endang Wahyu Pamungkas      3
# 4    1409869614          Soumitra Ghosh      4
# ..          ...                     ...    ...
# 316         NaN                     NaN    316
# 317         NaN                     NaN    317
# 318    69405544    Heiko Motschenbacher    318
# 319   104954883               L. Graham    319
# 320   143965359              Wendy Chan    320
#
# [321 rows x 3 columns]

# %% [markdown]
# Let's check if the combinations are unique to each author. (Can also check with the sizes)
#
# This result could be useful later as well, for analysis.

# %%
# to get unique combinations of the authors and names
nested_authors1_comb = nested_authors1.groupby(['author_1_id','author_1_name']).size().reset_index().rename(columns={0:'count'})
nested_authors1_comb = nested_authors1_comb.sort_values(by='count', ascending=False)
nested_authors1_comb
# Out:
#     author_1_id                              author_1_name  count
# 21   1409250207                             J. García-Díaz      4
# 48      1847803                                 E. Fersini      3
# 157     9278845                     Endang Wahyu Pamungkas      3
# 6     115237513                    Nahia Idoiaga Mondragón      3
# 62   2065405590                                   M. Fahim      3
# ..          ...                                        ...    ...
# 57   2053441697                                   E. White      1
# 58   2054429931                             Elizabeth Reid      1
# 60   2057733996                              Julius Reimer      1
# 61   2061490804  Francimaria Rayanne dos Santos Nascimento      1
# 80   2124956382                        Daisy Indira Barrón      1
#
# [160 rows x 3 columns]

# %% [markdown]
# Now, use dictionary to map the IDs to the names for later use.

# %%
auth_dict_1 = nested_authors1_comb.set_index('author_1_id').to_dict()['author_1_name']
auth_dict_1
# Out:
# {'1409250207': 'J. García-Díaz',
#  '1847803': 'E. Fersini',
#  '9278845': 'Endang Wahyu Pamungkas',
#  '115237513': 'Nahia Idoiaga Mondragón',
#  '2065405590': 'M. Fahim',
#  '2117276459': 'Sayma Sultana',
#  '73456815': 'J. Ringrose',
#  '1995519339': 'Pedro Orgeira-Crespo',
#  '2057093464': 'Mansi Mahendru',
#  '3455118': 'Flor Miriam Plaza del Arco',
#  '3442296': 'Harika Abburi',
#  '33621471': 'Paula Fortuna',
#  '3298993': 'V. Swami',
#  '1409869614': 'Soumitra Ghosh',
#  '1403518310': 'F. Rodríguez‐Sánchez',
#  '95925384': 'Habibe Karayigit',
#  '116155021': 'Jemma Tosh',
#  '74733212': 'J. Kwarteng',
#  '7675229': 'Simona Frenda',
#  '2196746400': 'Rizkyta Shainy Angeline',
#  '2183083803': 'Muhammad Amien Ibrahim',
#  '40866783': 'Sonja Erikainen',
#  '4033643': 'Courtland S. Hyatt',
#  '40066064': 'Jonah A. Berger',
#  '40059516': 'Kaitlynn Mendes',
#  '38598921': 'Ezat Ahmadzadeh',
#  '3751771': 'Tammi Arford',
#  '37415113': 'Jennifer D. Rubin',
#  '36715403': 'Sarah Masud',
#  '36328737': 'Pulkit Parikh',
#  '2188122986': 'Antonio Daniel García Rojas',
#  '34705135': 'C. Bosco',
#  '2639305': 'Marzieh Mozafari',
#  '2198249048': 'Sneha Chinivar',
#  '2737827': 'Bertie Vidgen',
#  '3426568': 'J. DeCook',
#  '2366554': 'Jenny Sundén',
#  '3314336': 'Salar Mohtaj',
#  '2388884': 'S. Abarna',
#  '32556330': 'Mohit Chandra',
#  '32404638': 'Suman Dowlagar',
#  '3139980': 'Jaigris Hodson',
#  '4552203': 'Sari M. van Anders',
#  '2545574': 'K. Katsarou',
#  '2886725': 'Svetlana Kiritchenko',
#  '2816085': 'Y. Djenouri',
#  '2905929': 'Jan Kocoń',
#  '48263975': 'C. Allely',
#  '46991154': 'Angelina Wang',
#  '5745475': 'R. Merkin',
#  '66825750': 'Athina Karatzogianni',
#  '67096342': 'Nuha Albadi',
#  '6914117': 'Khandis R. Blake',
#  '69362038': 'J. Papcunová',
#  '69405544': 'Heiko Motschenbacher',
#  '70369378': 'Y. Sone',
#  '72103816': 'Ursula Lutzky',
#  '73773451': 'Patricia Chiril',
#  '81117375': 'Kimberly B. Stratton',
#  '82023287': 'Stephan F. Miescher',
#  '83528971': 'T. Esnard',
#  '83863478': 'Andrea Kessler',
#  '87805847': 'Seppo Poutanen',
#  '90492940': 'S. Connell',
#  '93287099': 'Y. Paat',
#  '6473723': 'S. Murnen',
#  '5522652': 'A. Tabassum',
#  '47370338': 'M. Pease',
#  '5489876': 'J. Serano',
#  '47933250': 'Xiao Huang',
#  '48142114': 'Amrita Basu',
#  '2147085248': 'Carla Fernández Melendres',
#  '48275690': 'Wenjie Yin',
#  '48678884': 'B. Brogaard',
#  '49181304': 'S. Akhtar',
#  '49273166': 'R. Gass',
#  '49599054': 'R. Hill',
#  '50000230': 'R. Pringle',
#  '50549561': 'V. Balakrishnan',
#  '50978378': 'Jasmine DeHart',
#  '51443250': 'Shivang Agarwal',
#  '51912336': 'D. Herbenick',
#  '5400392': 'B. Earp',
#  '5448562': 'V. Rajah',
#  '2179540455': 'Jeanne C Desbuleux',
#  '100683617': 'Siobhan McAndrew',
#  '2146694845': 'S. Marjanovic',
#  '1410406981': 'F. Plaza-Del-Arco',
#  '143927736': 'Theo Lynn',
#  '143965359': 'Wendy Chan',
#  '144155890': 'J. Fuerst',
#  '144294552': 'Aiqi Jiang',
#  '144607761': 'A. Basile',
#  '144810681': 'N. Krieger',
#  '14523412': 'M. Bosworth',
#  '145455196': 'J. Mountford',
#  '145778984': 'Lucia Busso',
#  '145799536': 'S. Ward',
#  '146156211': 'Andraz Pelicon',
#  '146843835': 'Giuseppina Scotto di Carlo',
#  '151201979': 'S. Brooke',
#  '151464612': 'Marcas Mac Coinnigh',
#  '15165355': 'S. Haslanger',
#  '143752702': 'Paolo Rosso',
#  '1410329617': 'Óscar Apolinario-Arzube',
#  '2145364729': 'Zulqarnain Nazir',
#  '1404826354': 'J. Benítez-Andrades',
#  '103835404': 'Corinna Peil',
#  '104954883': 'L. Graham',
#  '113847353': 'Matthew Oware',
#  '114674117': 'Dana Schowalter',
#  '115297741': 'Maja Brandt Andreasen',
#  '116344697': 'B. Trifiro',
#  '116729741': 'E. Brodersen',
#  '117018834': 'Bharathi Raja Chakravarthi',
#  '118020305': 'Sean R. Sadri',
#  '11807047': 'A. Shahvisi',
#  '118617079': 'Stefan Dascalu',
#  '119305632': 'Corinna Lenhardt',
#  '134805041': 'Tharindu Ranasinghe',
#  '1387502231': 'Daniyar Sultan',
#  '1403613501': 'Teresa Piñeiro-Otero',
#  '15365233': 'R. Cliquet',
#  '15971377': 'M. A. Wani',
#  '1693665245': 'V. Sojo',
#  '1695993': 'Julian Risch',
#  '2085214622': 'Hiren Madhu',
#  '2085349122': 'Hiram Reyes-Sosa',
#  '20878377': 'Johan Brännmark',
#  '2090721311': 'J. Vergel',
#  '2104105732': 'Lisa Hodge',
#  '2110580052': 'Hieu Nguyen',
#  '2112144346': 'Muyang Li',
#  '2114853264': 'Gregorio Arturo Reyes González',
#  '2117662109': 'Kjell Vowles',
#  '2121386115': 'Marta Marchiori Manerba',
#  '2121589587': 'Gregorio Arturo Reyes González',
#  '2123504137': 'A. Y. Muaad',
#  '103602384': 'Endah Triastuti',
#  '2130514463': 'D. A. Rodríguez',
#  '2141072745': 'Gabriel Ichcanziho Pérez-Landa',
#  '2082347079': 'Silvia Lazzardi',
#  '2077526144': 'Carlos Castorena',
#  '2071355520': 'H. Everett',
#  '2021583549': 'Ignacio Blanco-Alfonso',
#  '1737785262': 'Hafiz Hassaan Saeed',
#  '1752477854': 'Mar Cánovas-García',
#  '1827690': 'Jane Bailey',
#  '1999125': 'Óscar Araque',
#  '2004698056': 'Maibam Debina Devi',
#  '2007556027': 'Plaza-Del-ArcoFlor-Miriam',
#  '2023723083': 'Abir Rahali',
#  '2066010806': 'Haris Bin Zia',
#  '2032196403': 'Fatimah Alkomah',
#  '2032578': 'F. Gasparini',
#  '2053441697': 'E. White',
#  '2054429931': 'Elizabeth Reid',
#  '2057733996': 'Julius Reimer',
#  '2061490804': 'Francimaria Rayanne dos Santos Nascimento',
#  '2124956382': 'Daisy Indira Barrón'}

# %%
# Following the same technique from the previous author 1 set till authro 6

# Author 2
nested_authors2 = pd.json_normalize(authors[1]).rename(columns={'authorId':'author_2_id', 'name':'author_2_name'})
nested_authors2['index'] = nested_authors2.index
nested_authors2_comb = nested_authors2.groupby(['author_2_id','author_2_name']).size().reset_index().rename(columns={0:'count'})
nested_authors2_comb = nested_authors2_comb.sort_values(by='count', ascending=False)
auth_dict_2 = nested_authors2_comb.set_index('author_2_id').to_dict()['author_2_name']

# Author 3
nested_authors3 = pd.json_normalize(authors[2]).rename(columns={'authorId':'author_3_id', 'name':'author_3_name'})
nested_authors3['index'] = nested_authors3.index
nested_authors3_comb = nested_authors3.groupby(['author_3_id','author_3_name']).size().reset_index().rename(columns={0:'count'})
nested_authors3_comb = nested_authors3_comb.sort_values(by='count', ascending=False)
auth_dict_3 = nested_authors3_comb.set_index('author_3_id').to_dict()['author_3_name']

# Author 4
nested_authors4 = pd.json_normalize(authors[3]).rename(columns={'authorId':'author_4_id', 'name':'author_4_name'})
nested_authors4['index'] = nested_authors4.index
nested_authors4_comb = nested_authors4.groupby(['author_4_id','author_4_name']).size().reset_index().rename(columns={0:'count'})
nested_authors4_comb = nested_authors4_comb.sort_values(by='count', ascending=False)
auth_dict_4 = nested_authors4_comb.set_index('author_4_id').to_dict()['author_4_name']

# Author 5
nested_authors5 = pd.json_normalize(authors[4]).rename(columns={'authorId':'author_5_id', 'name':'author_5_name'})
nested_authors5['index'] = nested_authors5.index
nested_authors5_comb = nested_authors5.groupby(['author_5_id','author_5_name']).size().reset_index().rename(columns={0:'count'})
nested_authors5_comb = nested_authors5_comb.sort_values(by='count', ascending=False)
auth_dict_5 = nested_authors5_comb.set_index('author_5_id').to_dict()['author_5_name']

# Author 6
nested_authors6 = pd.json_normalize(authors[5]).rename(columns={'authorId':'author_6_id', 'name':'author_6_name'})
nested_authors6['index'] = nested_authors6.index
nested_authors6_comb = nested_authors6.groupby(['author_6_id','author_6_name']).size().reset_index().rename(columns={0:'count'})
nested_authors6_comb = nested_authors6_comb.sort_values(by='count', ascending=False)
auth_dict_6 = nested_authors6_comb.set_index('author_6_id').to_dict()['author_6_name']

# %% [markdown]
# #### Merge the dataframes for the authors

# %%
#only run once
df = pd.merge(df, nested_authors1, on="index", how="left")
df = pd.merge(df, nested_authors2, on="index", how="left")
df = pd.merge(df, nested_authors3, on="index", how="left")
df = pd.merge(df, nested_authors4, on="index", how="left")
df = pd.merge(df, nested_authors5, on="index", how="left")
df = pd.merge(df, nested_authors6, on="index", how="left")

# %% [markdown]
# Now drop the ```authors``` column.

# %%
df = df.drop(columns=['authors'])

# %% [markdown]
# ### Author's data

# %%
authors_data = pd.json_normalize(df['author_data'])
authors_data
# Out:
#                                                     0   \
# 0    {'authorId': '2085214622', 'affiliations': [],...
# 1    {'authorId': '2198249048', 'affiliations': [],...
# 2    {'authorId': '1409869614', 'affiliations': ['I...
# 3    {'authorId': '9278845', 'affiliations': [], 'p...
# 4    {'authorId': '1409869614', 'affiliations': ['I...
# ..                                                 ...
# 316                                               None
# 317                                               None
# 318  {'authorId': '69405544', 'affiliations': [], '...
# 319  {'authorId': '104954883', 'affiliations': [], ...
# 320  {'authorId': '143965359', 'affiliations': [], ...
#
#                                                     1   \
# 0    {'authorId': '2057059204', 'affiliations': [],...
# 1    {'authorId': '2198254237', 'affiliations': [],...
# 2    {'authorId': '1734904', 'affiliations': [], 'p...
# 3    {'authorId': '3101511', 'affiliations': ['Univ...
# 4    {'authorId': '2194830832', 'affiliations': [],...
# ..                                                 ...
# 316                                               None
# 317                                               None
# 318                                               None
# 319                                               None
# 320  {'authorId': '8394097', 'affiliations': [], 'p...
#
#                                                     2   \
# 0    {'authorId': '33682998', 'affiliations': ['LDR...
# 1    {'authorId': '2198254207', 'affiliations': [],...
# 2    {'authorId': '145532184', 'affiliations': [], ...
# 3    {'authorId': '1787198', 'affiliations': [], 'p...
# 4    {'authorId': '1734904', 'affiliations': [], 'p...
# ..                                                 ...
# 316                                               None
# 317                                               None
# 318                                               None
# 319                                               None
# 320  {'authorId': '48014805', 'affiliations': [], '...
#
#                                                     3   \
# 0    {'authorId': '32416012', 'affiliations': ['Uni...
# 1    {'authorId': '2093461647', 'affiliations': [],...
# 2                                                 None
# 3                                                 None
# 4    {'authorId': '145532184', 'affiliations': [], ...
# ..                                                 ...
# 316                                               None
# 317                                               None
# 318                                               None
# 319                                               None
# 320                                               None
#
#                                                     4     5     6     7   \
# 0    {'authorId': '1911868', 'affiliations': [], 'p...  None  None  None
# 1                                                 None  None  None  None
# 2                                                 None  None  None  None
# 3                                                 None  None  None  None
# 4                                                 None  None  None  None
# ..                                                 ...   ...   ...   ...
# 316                                               None  None  None  None
# 317                                               None  None  None  None
# 318                                               None  None  None  None
# 319                                               None  None  None  None
# 320                                               None  None  None  None
#
#        8     9   ...    90    91    92    93    94    95    96    97    98  \
# 0    None  None  ...  None  None  None  None  None  None  None  None  None
# 1    None  None  ...  None  None  None  None  None  None  None  None  None
# 2    None  None  ...  None  None  None  None  None  None  None  None  None
# 3    None  None  ...  None  None  None  None  None  None  None  None  None
# 4    None  None  ...  None  None  None  None  None  None  None  None  None
# ..    ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 316  None  None  ...  None  None  None  None  None  None  None  None  None
# 317  None  None  ...  None  None  None  None  None  None  None  None  None
# 318  None  None  ...  None  None  None  None  None  None  None  None  None
# 319  None  None  ...  None  None  None  None  None  None  None  None  None
# 320  None  None  ...  None  None  None  None  None  None  None  None  None
#
#        99
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# ..    ...
# 316  None
# 317  None
# 318  None
# 319  None
# 320  None
#
# [321 rows x 100 columns]

# %%
author1_data = pd.json_normalize(authors_data[0])
author1_data['index'] = author1_data.index
author1_data
# Out:
#        authorId                                   affiliations  paperCount  \
# 0    2085214622                                             []         5.0
# 1    2198249048                                             []         1.0
# 2    1409869614  [Indian Institute of Technology Patna, India]        24.0
# 3       9278845                                             []        19.0
# 4    1409869614  [Indian Institute of Technology Patna, India]        24.0
# ..          ...                                            ...         ...
# 316         NaN                                            NaN         NaN
# 317         NaN                                            NaN         NaN
# 318    69405544                                             []       100.0
# 319   104954883                                             []        42.0
# 320   143965359                                             []        22.0
#
#      citationCount  hIndex  index
# 0            141.0     3.0      0
# 1              0.0     0.0      1
# 2             69.0     4.0      2
# 3            334.0    11.0      3
# 4             69.0     4.0      4
# ..             ...     ...    ...
# 316            NaN     NaN    316
# 317            NaN     NaN    317
# 318         1000.0    15.0    318
# 319          235.0     7.0    319
# 320          320.0     7.0    320
#
# [321 rows x 6 columns]

# %% [markdown]
# The affiliation column looks empty for most of them. Check to see how many are not null.

# %%
author1_data.affiliations.value_counts()
# not that useful to keep it then
# Out:
# []                                                     177
# [Indian Institute of Technology Patna, India]            2
# [National University of Ireland Galway]                  1
# [University of Wolverhampton]                            1
# [Télécom SudParis, Institut Polytechnique de Paris]      1
# [Wroclaw University of Technology]                       1
# [Georgia Institute of Technology]                        1
# [queen mary university of london]                        1
# [Hasso Plattner Institute, University of Potsdam]        1
# Name: affiliations, dtype: int64

# %%
# Change the names to avoid duplication of values while merging
author1_data = author1_data.rename(columns={
    'paperCount': 'author_1_paperCount', 'citationCount': 'author_1_citationCount', 'hIndex': 'author_1_hIndex'
})
# Drop the unneccessary columns, including the authorId, as it is already there from the previous dataframe
author1_data = author1_data.drop(columns=['authorId', 'affiliations'])
author1_data
# Out:
#      author_1_paperCount  author_1_citationCount  author_1_hIndex  index
# 0                    5.0                   141.0              3.0      0
# 1                    1.0                     0.0              0.0      1
# 2                   24.0                    69.0              4.0      2
# 3                   19.0                   334.0             11.0      3
# 4                   24.0                    69.0              4.0      4
# ..                   ...                     ...              ...    ...
# 316                  NaN                     NaN              NaN    316
# 317                  NaN                     NaN              NaN    317
# 318                100.0                  1000.0             15.0    318
# 319                 42.0                   235.0              7.0    319
# 320                 22.0                   320.0              7.0    320
#
# [321 rows x 4 columns]

# %% [markdown]
# Now for the authors from 2 to 6.

# %%
# Author 2
author2_data = pd.json_normalize(authors_data[1]).rename(columns={
    'paperCount': 'author_2_paperCount', 'citationCount': 'author_2_citationCount', 'hIndex': 'author_2_hIndex'
})
author2_data['index'] = author2_data.index
author2_data = author2_data.drop(columns=['authorId', 'affiliations'])

# Author 3
author3_data = pd.json_normalize(authors_data[2]).rename(columns={
    'paperCount': 'author_3_paperCount', 'citationCount': 'author_3_citationCount', 'hIndex': 'author_3_hIndex'
})
author3_data['index'] = author3_data.index
author3_data = author3_data.drop(columns=['authorId', 'affiliations'])

# Author 4
author4_data = pd.json_normalize(authors_data[3]).rename(columns={
    'paperCount': 'author_4_paperCount', 'citationCount': 'author_4_citationCount', 'hIndex': 'author_4_hIndex'
})
author4_data['index'] = author4_data.index
author4_data = author4_data.drop(columns=['authorId', 'affiliations'])

# Author 5
author5_data = pd.json_normalize(authors_data[4]).rename(columns={
    'paperCount': 'author_5_paperCount', 'citationCount': 'author_5_citationCount', 'hIndex': 'author_5_hIndex'
})
author5_data['index'] = author5_data.index
author5_data = author5_data.drop(columns=['authorId', 'affiliations'])

# Author 6
author6_data = pd.json_normalize(authors_data[5]).rename(columns={
    'paperCount': 'author_6_paperCount', 'citationCount': 'author_6_citationCount', 'hIndex': 'author_6_hIndex'
})
author6_data['index'] = author6_data.index
author6_data = author6_data.drop(columns=['authorId', 'affiliations'])

# %% [markdown]
# #### Merge the dataframes for each authors

# %%
#only run once
df = pd.merge(df, author1_data, on="index", how="left")
df = pd.merge(df, author2_data, on="index", how="left")
df = pd.merge(df, author3_data, on="index", how="left")
df = pd.merge(df, author4_data, on="index", how="left")
df = pd.merge(df, author5_data, on="index", how="left")
df = pd.merge(df, author6_data, on="index", how="left")

# %% [markdown]
# Drop the ```author_data``` column

# %%
df = df.drop(columns=['author_data'])

# %%
pd.json_normalize(df.publicationVenue)
# we only need the name, which already exists in the column 'venue', so we can drop this.
# Out:
#                                        id                               name  \
# 0    987139ae-a65d-49bb-aaf6-fb764dc40b19   Expert systems with applications
# 1    ec253390-208b-4979-9d5f-c9f654ad6181            Entertainment Computing
# 2                                     NaN                                NaN
# 3    68fd8242-3be0-4b1e-8b5d-ad0a8a02db12  Personal and Ubiquitous Computing
# 4    12fff95b-d469-49a0-84a5-4fd4696c3f28            Knowledge-Based Systems
# ..                                    ...                                ...
# 316                                   NaN                                NaN
# 317                                   NaN                                NaN
# 318                                   NaN                                NaN
# 319                                   NaN                                NaN
# 320                                   NaN                                NaN
#
#         type                                    alternate_names       issn  \
# 0    journal  [Expert syst appl, Expert Systems With Applica...  0957-4174
# 1    journal                                 [Entertain Comput]  1875-9521
# 2        NaN                                                NaN        NaN
# 3    journal                           [Pers Ubiquitous Comput]  1617-4909
# 4    journal  [Knowl Based Syst, Knowledge Based Systems, Kn...  0950-7051
# ..       ...                                                ...        ...
# 316      NaN                                                NaN        NaN
# 317      NaN                                                NaN        NaN
# 318      NaN                                                NaN        NaN
# 319      NaN                                                NaN        NaN
# 320      NaN                                                NaN        NaN
#
#                                                    url  \
# 0    https://www.journals.elsevier.com/expert-syste...
# 1    https://www.journals.elsevier.com/entertainmen...
# 2                                                  NaN
# 3     http://www.springer.com/computer/hci/journal/779
# 4    http://www.elsevier.com/wps/find/journaldescri...
# ..                                                 ...
# 316                                                NaN
# 317                                                NaN
# 318                                                NaN
# 319                                                NaN
# 320                                                NaN
#
#                                         alternate_urls alternate_issns
# 0    [https://www.sciencedirect.com/journal/expert-...             NaN
# 1    [http://www.sciencedirect.com/science/journal/...             NaN
# 2                                                  NaN             NaN
# 3    [https://link.springer.com/journal/volumesAndI...             NaN
# 4    [https://www.journals.elsevier.com/knowledge-b...             NaN
# ..                                                 ...             ...
# 316                                                NaN             NaN
# 317                                                NaN             NaN
# 318                                                NaN             NaN
# 319                                                NaN             NaN
# 320                                                NaN             NaN
#
# [321 rows x 8 columns]

# %%
df = df.drop(columns=['publicationVenue'])

# %% [markdown]
# #### Discipline types
# Now we have to drop the original authors variable as it is a dictionary and change the ```fieldsOfStudy``` to hashable form.
#
# Otherwise it gives ```TypeError: unhashable type: 'dict'``` error on performing drop_duplicates().

# %%
df.fieldsOfStudy
# Out:
# 0                    None
# 1                    None
# 2                    None
# 3      [Computer Science]
# 4      [Computer Science]
#               ...
# 316                   NaN
# 317                   NaN
# 318    [Computer Science]
# 319             [History]
# 320           [Sociology]
# Name: fieldsOfStudy, Length: 321, dtype: object

# %% [markdown]
# Check if any null value is present.

# %%
df.fieldsOfStudy.isna().sum() # Quite a lot.
# Out:
# 175

# %% [markdown]
# Do the necessary changes to change the type.

# %%
fields = df.fieldsOfStudy.copy()

fields = fields.explode()
fields_index = fields.index.to_list()
fields_name = fields.to_list()
fields = [fields_index, fields_name]
fields = pd.DataFrame(fields).transpose()
fields.columns = ['index', 'name']

fields = fields.groupby(by='index')['name'].apply(lambda x:x.str.cat(sep=", ")).reset_index(drop=True)
fields = pd.DataFrame(fields)
fields['index'] = fields.index

fields
# Out:
#                  name  index
# 0                          0
# 1                          1
# 2                          2
# 3    Computer Science      3
# 4    Computer Science      4
# ..                ...    ...
# 316                      316
# 317                      317
# 318  Computer Science    318
# 319           History    319
# 320         Sociology    320
#
# [321 rows x 2 columns]

# %%
fields_type = fields['name'].to_list()
unique_fields = []
for i in fields_type:
    i = i.split(", ")
    for j in i:
        if j not in unique_fields:
            if j != '':
                unique_fields.append(j)
        else:
            continue

unique_fields
# Out:
# ['Computer Science',
#  'Medicine',
#  'History',
#  'Sociology',
#  'Psychology',
#  'Political Science',
#  'Art',
#  'Business',
#  'Economics',
#  'Geography',
#  'Biology',
#  'Engineering']

# %% [markdown]
# Now we can merge this dataframe to the original one, and drop the fieldsOfStudy variable to replace with this one.

# %%
# drop the column 'fieldsOfStudy'
df = df.drop(columns=['fieldsOfStudy'])

# merge the above dataframe to this one
df = pd.merge(df, fields, on="index", how="left").rename(columns={'name': 'fieldsOfStudy'})

# %% [markdown]
# #### Remove duplicate columns

# %%
df['dc:creator'].iloc[0] #not important
# Out:
# {'author': [{'ce:given-name': 'Hiren',
#    'preferred-name': {'ce:given-name': 'Hiren',
#     'ce:initials': 'H.',
#     'ce:surname': 'Madhu',
#     'ce:indexed-name': 'Madhu H.'},
#    '@seq': '1',
#    'ce:initials': 'H.',
#    '@_fa': 'true',
#    'affiliation': [{'@id': '60014097',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60014097'},
#     {'@id': '125175992',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/125175992'}],
#    'ce:surname': 'Madhu',
#    '@auid': '57222510587',
#    'author-url': 'https://api.elsevier.com/content/author/author_id/57222510587',
#    'ce:indexed-name': 'Madhu H.'}]}

# %%
df[['dc:description', 'abstract']] # Remove the second one as it has some null values
# Out:
#                                         dc:description  \
# 0    © 2022 Elsevier LtdThe spread of Hate Speech o...
# 1    © 2022 Elsevier B.V.The enormous growth of soc...
# 2    © 2022 Elsevier LtdDetecting suicidal tendenci...
# 3    © 2021, The Author(s).Abusive language is an i...
# 4    © 2022 Elsevier B.V.As the number of non-nativ...
# ..                                                 ...
# 316  Argues that South Africa's apartheid system of...
# 317  In Russia during the second half of the eighte...
# 318  © 2012 - John Benjamins B.V.This comprehensive...
# 319  © 2012 by Oxford University Press, Inc. All ri...
# 320  © 2005 by Lawrence Erlbaum Associates, Inc.Thi...
#
#                                               abstract
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 316                                                NaN
# 317                                                NaN
# 318  This comprehensive, state-of-the-art bibliogra...
# 319  Preface Introduction 1. Danger and Desire: Rap...
# 320  Only for you today! Discover your favourite wo...
#
# [321 rows x 2 columns]

# %%
df[['dc:title', 'title']] # Remove the second one as it has different langauge for some
# Out:
#                                               dc:title  \
# 0    Detecting offensive speech in conversational c...
# 1    Online offensive behaviour in socialmedia: Det...
# 2    VAD-assisted multitask transformer framework f...
# 3    Towards multidomain and multilingual abusive l...
# 4    Multitasking of sentiment detection and emotio...
# ..                                                 ...
# 316  Sex in transition: Remaking gender and race in...
# 317  From the womb to the body politic: Raising the...
# 318  An interdisciplinary bibliography on language,...
# 319  State of Peril: Race and Rape in South African...
# 320      Women, madness and the law: A feminist reader
#
#                                                  title
# 0    Detecting offensive speech in conversational c...
# 1    Online offensive behaviour in socialmedia: Det...
# 2    VAD-assisted multitask transformer framework f...
# 3    Towards multidomain and multilingual abusive l...
# 4    Multitasking of sentiment detection and emotio...
# ..                                                 ...
# 316                                                NaN
# 317                                                NaN
# 318  An Interdisciplinary Bibliography on Language,...
# 319  State of Peril: Race and Rape in South African...
# 320     Women, Madness and the Law : A Feminist Reader
#
# [321 rows x 2 columns]

# %% [markdown]
# Based on that, remove these columns from the dataframe. Also remove the rows with no DOIs.

# %%
# drop these columns and change the names of the duplicated columns
df = df.drop(columns=['title', 'abstract', 'dc:creator']).rename(columns={'dc:title': 'title', 'dc:description': 'abstract'})
# 1598 rows (for 1st query)

# Drop rows with no DOIs
df = df.dropna(subset=['prism:doi']) 
# 1548 rows (for 1st query)

# Check of some values are duplicated. If so, remove them based on 'title' and 'abstract' column
df = df.drop_duplicates(subset=['title', 'abstract'], keep="first")
# 1548 rows -- no duplicates! (for 1st query)

# %% [markdown]
# Now we can store this in a csv file, so that we do not need to use the APIs everytime to fetch the data.

# %%
#df.to_csv('search_data.csv')
#df.to_csv('search_data_1.csv')
#df.to_csv('search_data_2.csv')
df.to_csv('search_data_3.csv')
